# %% [markdown]
# # Installs

# %%
# %pip install -U openai json-repair google-genai gliclass rapidfuzz "transformers>=4.48.0" retry ipywidgets widgetsnbextension pandas-profiling readtime optuna bertopic supabase
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProxyError('Cannot connect to proxy.', TimeoutError('_ssl.c:990: The handshake operation timed out'))': /simple/openai/
# Collecting openai
#   Using cached openai-1.77.0-py3-none-any.whl.metadata (25 kB)
# Collecting json-repair
#   Using cached json_repair-0.44.1-py3-none-any.whl.metadata (12 kB)
# Collecting google-genai
#   Using cached google_genai-1.13.0-py3-none-any.whl.metadata (32 kB)
# Collecting gliclass
#   Using cached gliclass-0.1.11-py3-none-any.whl.metadata (4.9 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.13.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting transformers>=4.48.0
#   Using cached transformers-4.51.3-py3-none-any.whl.metadata (38 kB)
# Collecting retry
#   Using cached retry-0.9.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting widgetsnbextension
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting readtime
#   Using cached readtime-3.0.0.tar.gz (6.3 kB)
#   Preparing metadata (setup.py) ... done
# Collecting optuna
#   Using cached optuna-4.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting bertopic
#   Using cached bertopic-0.17.0-py3-none-any.whl.metadata (23 kB)
# Collecting supabase
#   Using cached supabase-2.15.1-py3-none-any.whl.metadata (11 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Using cached anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.4.0 (from openai)
#   Downloading jiter-0.9.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Using cached pydantic-2.11.4-py3-none-any.whl.metadata (66 kB)
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from openai) (4.13.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.33.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-genai)
#   Using cached google_auth-2.40.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting requests<3.0.0,>=2.28.1 (from google-genai)
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-15.0.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.28.1->google-genai)
#   Downloading charset_normalizer-3.4.2-cp310-cp310-macosx_10_9_universal2.whl.metadata (35 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.28.1->google-genai)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numpy<2.0.0,>=1.26.4 (from gliclass)
#   Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# Collecting scikit-learn<2.0.0,>=1.0.0 (from gliclass)
#   Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Collecting torch<3.0.0,>=2.0.0 (from gliclass)
#   Downloading torch-2.7.0-cp310-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting transformers>=4.48.0
#   Using cached transformers-4.48.2-py3-none-any.whl.metadata (44 kB)
# Collecting filelock (from transformers>=4.48.0)
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers>=4.48.0)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from transformers>=4.48.0) (25.0)
# Collecting pyyaml>=5.1 (from transformers>=4.48.0)
#   Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting regex!=2019.12.17 (from transformers>=4.48.0)
#   Downloading regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<0.22,>=0.21 (from transformers>=4.48.0)
#   Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.1 (from transformers>=4.48.0)
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.24.0->transformers>=4.48.0)
#   Downloading fsspec-2025.3.2-py3-none-any.whl.metadata (11 kB)
# Collecting scipy>=1.6.0 (from scikit-learn<2.0.0,>=1.0.0->gliclass)
#   Downloading scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn<2.0.0,>=1.0.0->gliclass)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn<2.0.0,>=1.0.0->gliclass)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting sympy>=1.13.3 (from torch<3.0.0,>=2.0.0->gliclass)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch<3.0.0,>=2.0.0->gliclass)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch<3.0.0,>=2.0.0->gliclass)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: decorator>=3.4.2 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from retry) (5.2.1)
# Collecting py<2.0.0,>=1.4.26 (from retry)
#   Using cached py-1.11.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: comm>=0.1.3 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipywidgets) (8.36.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting ydata-profiling (from pandas-profiling)
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting beautifulsoup4>=4.0.1 (from readtime)
#   Downloading beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# Collecting markdown2>=2.4.3 (from readtime)
#   Using cached markdown2-2.5.3-py3-none-any.whl.metadata (2.1 kB)
# Collecting pyquery>=1.2 (from readtime)
#   Using cached pyquery-2.0.1-py3-none-any.whl.metadata (9.0 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Using cached alembic-1.15.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting colorlog (from optuna)
#   Using cached colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting sqlalchemy>=1.4.2 (from optuna)
#   Downloading sqlalchemy-2.0.40-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.6 kB)
# Collecting hdbscan>=0.8.29 (from bertopic)
#   Downloading hdbscan-0.8.40.tar.gz (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 518.0 kB/s eta 0:00:000:00:01m eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas>=1.1.5 (from bertopic)
#   Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (89 kB)
# Collecting plotly>=4.7.0 (from bertopic)
#   Using cached plotly-6.0.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting sentence-transformers>=0.4.1 (from bertopic)
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl.metadata (13 kB)
# Collecting umap-learn>=0.5.0 (from bertopic)
#   Using cached umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Collecting gotrue<3.0.0,>=2.11.0 (from supabase)
#   Using cached gotrue-2.12.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting postgrest<1.1,>0.19 (from supabase)
#   Using cached postgrest-1.0.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting realtime<2.5.0,>=2.4.0 (from supabase)
#   Using cached realtime-2.4.3-py3-none-any.whl.metadata (6.7 kB)
# Collecting storage3<0.12,>=0.10 (from supabase)
#   Using cached storage3-0.11.3-py3-none-any.whl.metadata (1.8 kB)
# Collecting supafunc<0.10,>=0.9 (from supabase)
#   Using cached supafunc-0.9.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting pyjwt<3.0.0,>=2.10.1 (from gotrue<3.0.0,>=2.11.0->supabase)
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting pytest-mock<4.0.0,>=3.14.0 (from gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached pytest_mock-3.14.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting h2<5,>=3 (from httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached h2-4.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[http2]<0.29,>=0.26->gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached hpack-4.1.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting deprecation<3.0.0,>=2.1.0 (from postgrest<1.1,>0.19->supabase)
#   Using cached deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting strenum<0.5.0,>=0.4.9 (from postgrest<1.1,>0.19->supabase)
#   Using cached StrEnum-0.4.15-py3-none-any.whl.metadata (5.3 kB)
# Collecting pytest>=6.2.5 (from pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting aiohttp<4.0.0,>=3.11.18 (from realtime<2.5.0,>=2.4.0->supabase)
#   Downloading aiohttp-3.11.18-cp310-cp310-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from realtime<2.5.0,>=2.4.0->supabase) (2.9.0.post0)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-14.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading frozenlist-1.6.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading multidict-6.4.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading propcache-0.3.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (10 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.11.18->realtime<2.5.0,>=2.4.0->supabase)
#   Downloading yarl-1.20.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (72 kB)
# Requirement already satisfied: six>=1.5 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.8.1->realtime<2.5.0,>=2.4.0->supabase) (1.17.0)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Using cached mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.0.1->readtime)
#   Downloading soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: jedi>=0.16 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Collecting pytz>=2020.1 (from pandas>=1.1.5->bertopic)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=1.1.5->bertopic)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Collecting narwhals>=1.15.1 (from plotly>=4.7.0->bertopic)
#   Downloading narwhals-1.38.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting lxml>=2.1 (from pyquery>=1.2->readtime)
#   Downloading lxml-5.4.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (3.5 kB)
# Collecting cssselect>=1.2.0 (from pyquery>=1.2->readtime)
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting iniconfig (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached iniconfig-2.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting pluggy<2,>=1.5 (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase)
#   Using cached pluggy-1.5.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting tomli>=1 (from pytest>=6.2.5->pytest-mock<4.0.0,>=3.14.0->gotrue<3.0.0,>=2.11.0->supabase)
#   Downloading tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Collecting Pillow (from sentence-transformers>=0.4.1->bertopic)
#   Downloading pillow-11.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch<3.0.0,>=2.0.0->gliclass)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting numba>=0.51.2 (from umap-learn>=0.5.0->bertopic)
#   Downloading numba-0.61.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic)
#   Using cached pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.2->umap-learn>=0.5.0->bertopic)
#   Downloading llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch<3.0.0,>=2.0.0->gliclass)
#   Downloading MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure_eval in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling->pandas-profiling)
#   Downloading matplotlib-3.10.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (11 kB)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Collecting htmlmin==0.1.12 (from ydata-profiling->pandas-profiling)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling->pandas-profiling)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling->pandas-profiling)
#   Downloading wordcloud-1.9.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba>=0.51.2 (from umap-learn>=0.5.0->bertopic)
#   Downloading numba-0.61.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling->pandas-profiling)
#   Downloading pywavelets-1.8.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Downloading fonttools-4.57.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Downloading kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading puremagic-1.29-py3-none-any.whl.metadata (5.8 kB)
# Using cached openai-1.77.0-py3-none-any.whl (662 kB)
# Using cached anyio-4.9.0-py3-none-any.whl (100 kB)
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading jiter-0.9.0-cp310-cp310-macosx_11_0_arm64.whl (321 kB)
# Downloading pydantic-2.11.4-py3-none-any.whl (443 kB)
# Downloading pydantic_core-2.33.2-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 532.4 kB/s eta 0:00:001m530.3 kB/s eta 0:00:01
# Using cached json_repair-0.44.1-py3-none-any.whl (22 kB)
# Using cached google_genai-1.13.0-py3-none-any.whl (164 kB)
# Using cached google_auth-2.40.0-py2.py3-none-any.whl (216 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp310-cp310-macosx_10_9_universal2.whl (201 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Using cached gliclass-0.1.11-py3-none-any.whl (32 kB)
# Using cached transformers-4.48.2-py3-none-any.whl (9.7 MB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Downloading numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 516.7 kB/s eta 0:00:00m eta 0:00:010:02:02
# Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 555.8 kB/s eta 0:00:00m eta 0:00:010:00:01
# Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Downloading torch-2.7.0-cp310-none-macosx_11_0_arm64.whl (68.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 554.5 kB/s eta 0:00:00m eta 0:00:010:00:04
# Downloading rapidfuzz-3.13.0-cp310-cp310-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 576.1 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Using cached retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# Using cached py-1.11.0-py2.py3-none-any.whl (98 kB)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Using cached optuna-4.3.0-py3-none-any.whl (386 kB)
# Using cached bertopic-0.17.0-py3-none-any.whl (150 kB)
# Using cached supabase-2.15.1-py3-none-any.whl (17 kB)
# Using cached gotrue-2.12.0-py3-none-any.whl (43 kB)
# Using cached h2-4.2.0-py3-none-any.whl (60 kB)
# Using cached hpack-4.1.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Using cached postgrest-1.0.1-py3-none-any.whl (22 kB)
# Using cached deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Using cached pytest_mock-3.14.0-py3-none-any.whl (9.9 kB)
# Using cached realtime-2.4.3-py3-none-any.whl (22 kB)
# Downloading aiohttp-3.11.18-cp310-cp310-macosx_11_0_arm64.whl (457 kB)
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading multidict-6.4.3-cp310-cp310-macosx_11_0_arm64.whl (37 kB)
# Using cached storage3-0.11.3-py3-none-any.whl (17 kB)
# Using cached StrEnum-0.4.15-py3-none-any.whl (8.9 kB)
# Using cached supafunc-0.9.4-py3-none-any.whl (7.8 kB)
# Downloading websockets-14.2-cp310-cp310-macosx_11_0_arm64.whl (160 kB)
# Downloading yarl-1.20.0-cp310-cp310-macosx_11_0_arm64.whl (94 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached alembic-1.15.2-py3-none-any.whl (231 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading beautifulsoup4-4.13.4-py3-none-any.whl (187 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading frozenlist-1.6.0-cp310-cp310-macosx_11_0_arm64.whl (122 kB)
# Downloading fsspec-2025.3.2-py3-none-any.whl (194 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached markdown2-2.5.3-py3-none-any.whl (48 kB)
# Downloading pandas-2.2.3-cp310-cp310-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 561.2 kB/s eta 0:00:001m560.9 kB/s eta 0:00:01
# Using cached plotly-6.0.1-py3-none-any.whl (14.8 MB)
# Downloading narwhals-1.38.0-py3-none-any.whl (338 kB)
# Downloading propcache-0.3.1-cp310-cp310-macosx_11_0_arm64.whl (45 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyquery-2.0.1-py3-none-any.whl (22 kB)
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading lxml-5.4.0-cp310-cp310-macosx_10_9_universal2.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 798.3 kB/s eta 0:00:001m780.7 kB/s eta 0:00:01
# Using cached pytest-8.3.5-py3-none-any.whl (343 kB)
# Using cached pluggy-1.5.0-py3-none-any.whl (20 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-macosx_11_0_arm64.whl (171 kB)
# Downloading regex-2024.11.6-cp310-cp310-macosx_11_0_arm64.whl (284 kB)
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
# Downloading scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 7.3 MB/s eta 0:00:007.3 MB/s eta 0:00:01
# Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading soupsieve-2.7-py3-none-any.whl (36 kB)
# Downloading sqlalchemy-2.0.40-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 9.0 MB/s eta 0:00:009.6 MB/s eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 8.2 MB/s eta 0:00:008.0 MB/s eta 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 8.4 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Using cached umap_learn-0.5.7-py3-none-any.whl (88 kB)
# Downloading llvmlite-0.44.0-cp310-cp310-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 5.5 MB/s eta 0:00:000:00:010:00:01:01
# Using cached pynndescent-0.5.13-py3-none-any.whl (56 kB)
# Using cached colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached iniconfig-2.1.0-py3-none-any.whl (6.0 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp310-cp310-macosx_11_0_arm64.whl (12 kB)
# Using cached mako-1.3.10-py3-none-any.whl (78 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pillow-11.2.1-cp310-cp310-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 6.1 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading matplotlib-3.10.0-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 4.7 MB/s eta 0:00:000:00:01m eta 0:00:01
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.61.0-cp310-cp310-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading phik-0.12.4-cp310-cp310-macosx_11_0_arm64.whl (655 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 655.9/655.9 kB 3.8 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.4-cp310-cp310-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 4.3 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading fonttools-4.57.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 3.7 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading wordcloud-1.9.4-cp310-cp310-macosx_11_0_arm64.whl (167 kB)
# Downloading puremagic-1.29-py3-none-any.whl (43 kB)
# Downloading pywavelets-1.8.0-cp310-cp310-macosx_11_0_arm64.whl (4.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 5.7 MB/s eta 0:00:005.4 MB/s eta 0:00:01
# Building wheels for collected packages: readtime, hdbscan, htmlmin
#   DEPRECATION: Building 'readtime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'readtime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for readtime (setup.py) ... done
#   Created wheel for readtime: filename=readtime-3.0.0-py3-none-any.whl size=6890 sha256=66c7e9218a7bcda2968b540134f326742c200b6d2dc40edd2ccc1258b4df0b02
#   Stored in directory: /Users/shiwenjie/Library/Caches/pip/wheels/7f/7f/fd/3ad5a2ac4aff28279c36445a67b8033441a2bfa89fa57b5718
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.40-cp310-cp310-macosx_11_0_arm64.whl size=745532 sha256=0e2262f5b98d94491ba4cf52b499e5581eec1fa9c7dd90df99d1a3a48d03a27e
#   Stored in directory: /Users/shiwenjie/Library/Caches/pip/wheels/54/ba/75/e1883bf767fda8494225c99b81fbf5e977e23459d35e93b301
#   DEPRECATION: Building 'htmlmin' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'htmlmin'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27161 sha256=1f7b9814246628f2dd1c494369809c03a21893d3ffc2a9bb44144d513ae71669
#   Stored in directory: /Users/shiwenjie/Library/Caches/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built readtime hdbscan htmlmin
# Installing collected packages: strenum, pytz, puremagic, mpmath, htmlmin, widgetsnbextension, websockets, urllib3, tzdata, typing-inspection, typeguard, tqdm, tomli, threadpoolctl, sympy, sqlalchemy, soupsieve, sniffio, safetensors, regex, rapidfuzz, pyyaml, pyparsing, pyjwt, pydantic-core, pyasn1, py, propcache, pluggy, Pillow, numpy, networkx, narwhals, multimethod, multidict, MarkupSafe, markdown2, lxml, llvmlite, kiwisolver, jupyterlab_widgets, json-repair, joblib, jiter, iniconfig, idna, hyperframe, hpack, h11, fsspec, frozenlist, fonttools, filelock, distro, deprecation, dacite, cycler, cssselect, colorlog, charset-normalizer, certifi, cachetools, attrs, async-timeout, annotated-types, aiohappyeyeballs, yarl, scipy, rsa, retry, requests, PyWavelets, pytest, pyquery, pydantic, pyasn1-modules, plotly, patsy, pandas, numba, Mako, jinja2, httpcore, h2, contourpy, beautifulsoup4, anyio, aiosignal, visions, torch, statsmodels, scikit-learn, readtime, pytest-mock, matplotlib, ipywidgets, imagehash, huggingface-hub, httpx, google-auth, alembic, aiohttp, wordcloud, tokenizers, seaborn, realtime, pynndescent, phik, optuna, openai, hdbscan, google-genai, ydata-profiling, umap-learn, transformers, supafunc, storage3, postgrest, gotrue, supabase, sentence-transformers, pandas-profiling, gliclass, bertopic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124/124 [bertopic] [pandas-profiling]orage3]ansformers]es]
# Successfully installed Mako-1.3.10 MarkupSafe-3.0.2 Pillow-11.2.1 PyWavelets-1.8.0 aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 alembic-1.15.2 annotated-types-0.7.0 anyio-4.9.0 async-timeout-5.0.1 attrs-25.3.0 beautifulsoup4-4.13.4 bertopic-0.17.0 cachetools-5.5.2 certifi-2025.4.26 charset-normalizer-3.4.2 colorlog-6.9.0 contourpy-1.3.2 cssselect-1.3.0 cycler-0.12.1 dacite-1.9.2 deprecation-2.1.0 distro-1.9.0 filelock-3.18.0 fonttools-4.57.0 frozenlist-1.6.0 fsspec-2025.3.2 gliclass-0.1.11 google-auth-2.40.0 google-genai-1.13.0 gotrue-2.12.0 h11-0.16.0 h2-4.2.0 hdbscan-0.8.40 hpack-4.1.0 htmlmin-0.1.12 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.30.2 hyperframe-6.1.0 idna-3.10 imagehash-4.3.1 iniconfig-2.1.0 ipywidgets-8.1.7 jinja2-3.1.6 jiter-0.9.0 joblib-1.5.0 json-repair-0.44.1 jupyterlab_widgets-3.0.15 kiwisolver-1.4.8 llvmlite-0.44.0 lxml-5.4.0 markdown2-2.5.3 matplotlib-3.10.0 mpmath-1.3.0 multidict-6.4.3 multimethod-1.12 narwhals-1.38.0 networkx-3.4.2 numba-0.61.0 numpy-1.26.4 openai-1.77.0 optuna-4.3.0 pandas-2.2.3 pandas-profiling-3.6.6 patsy-1.0.1 phik-0.12.4 plotly-6.0.1 pluggy-1.5.0 postgrest-1.0.1 propcache-0.3.1 puremagic-1.29 py-1.11.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.4 pydantic-core-2.33.2 pyjwt-2.10.1 pynndescent-0.5.13 pyparsing-3.2.3 pyquery-2.0.1 pytest-8.3.5 pytest-mock-3.14.0 pytz-2025.2 pyyaml-6.0.2 rapidfuzz-3.13.0 readtime-3.0.0 realtime-2.4.3 regex-2024.11.6 requests-2.32.3 retry-0.9.2 rsa-4.9.1 safetensors-0.5.3 scikit-learn-1.6.1 scipy-1.15.2 seaborn-0.13.2 sentence-transformers-4.1.0 sniffio-1.3.1 soupsieve-2.7 sqlalchemy-2.0.40 statsmodels-0.14.4 storage3-0.11.3 strenum-0.4.15 supabase-2.15.1 supafunc-0.9.4 sympy-1.14.0 threadpoolctl-3.6.0 tokenizers-0.21.1 tomli-2.2.1 torch-2.7.0 tqdm-4.67.1 transformers-4.48.2 typeguard-4.4.2 typing-inspection-0.4.0 tzdata-2025.2 umap-learn-0.5.7 urllib3-2.4.0 visions-0.8.1 websockets-14.2 widgetsnbextension-4.0.14 wordcloud-1.9.4 yarl-1.20.0 ydata-profiling-4.16.1
# Could not fetch URL https://pypi.org/simple/pip/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='pypi.org', port=443): Max retries exceeded with url: /simple/pip/ (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)'))) - skipping
# Note: you may need to restart the kernel to use updated packages.

# %%
#本地测试
# %pip install python-dotenv sqlalchemy psycopg2-binary pandas google-genai json-repair
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.1.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: sqlalchemy in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (2.0.40)
# Collecting psycopg2-binary
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)'))': /packages/e7/9a/7f4f2f031010bbfe6a02b4a15c01e12eb6b9b7b358ab33229f28baadbfc1/psycopg2_binary-2.9.10-cp310-cp310-macosx_14_0_arm64.whl.metadata
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)'))': /packages/e7/9a/7f4f2f031010bbfe6a02b4a15c01e12eb6b9b7b358ab33229f28baadbfc1/psycopg2_binary-2.9.10-cp310-cp310-macosx_14_0_arm64.whl.metadata
#   Downloading psycopg2_binary-2.9.10-cp310-cp310-macosx_14_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: pandas in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: google-genai in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (1.13.0)
# Requirement already satisfied: json-repair in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (0.44.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from sqlalchemy) (4.13.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-genai) (4.9.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-genai) (2.40.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-genai) (2.11.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-genai) (2.32.3)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-genai) (14.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.2.2)
# Requirement already satisfied: idna>=2.8 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from google-auth<3.0.0,>=2.14.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai) (0.6.1)
# Requirement already satisfied: six>=1.5 in /Users/shiwenjie/miniconda3/envs/meridian-ml/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Downloading psycopg2_binary-2.9.10-cp310-cp310-macosx_14_0_arm64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 3.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: python-dotenv, psycopg2-binary
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [psycopg2-binary]
# Successfully installed psycopg2-binary-2.9.10 python-dotenv-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Fetch events

# %%
import os
print(f"当前工作目录: {os.getcwd()}")
print(f"DATABASE_URL: {os.environ.get('DATABASE_URL', '未设置')}")
# Out:
# 当前工作目录: /Users/shiwenjie/code/github_repo/spider/meridian/apps/briefs
# DATABASE_URL: postgresql://postgres:709323@localhost:5432/shiwenjie

# %%
import importlib
import src.events

# 强制重新加载 src.events 模块
importlib.reload(src.events)

# 再次检查模块中的函数
print("重新加载后的模块属性:")
print([attr for attr in dir(src.events) if not attr.startswith('_')])

# 现在尝试导入 debug_database_connection
from src.events import debug_database_connection

# 测试函数
debug_database_connection()
# Out:
# 重新加载后的模块属性:
# ['BaseModel', 'Event', 'Optional', 'Source', 'date', 'datetime', 'debug_database_connection', 'field_validator', 'get_events', 'get_events_local', 'load_dotenv', 'os', 'pd', 'requests']
#
# ==== 开始数据库调试 ====
# 使用数据库连接: postgresql://postgres:709323@localhost:5432/shiwenjie
# 数据库连接测试: 成功 (1,)
# 数据库中的表: ['newsletter', 'reports', 'articles', 'sources']
# articles表的字段: ['id', 'title', 'url', 'publish_date', 'status', 'content_file_key', 'language', 'primary_location', 'completeness', 'content_quality', 'used_browser', 'event_summary_points', 'thematic_keywords', 'topic_tags', 'key_entities', 'content_focus', 'embedding', 'fail_reason', 'source_id', 'processed_at', 'created_at']
# articles表中的记录数: 20
# articles表中的示例记录: (5, 'Show HN: Moss – AI-Powered Semantic Search Running In-Browser (No Cloud)', 'https://twitter.com/inferedgeinc/status/1918918367752421693', datetime.datetime(2025, 5, 5, 23, 10, 52), 'FETCH_FAILED', None, None, None, None, None, None, None, None, None, None, None, None, 'ZodError', 1, datetime.datetime(2025, 5, 5, 23, 30, 13, 410000), datetime.datetime(2025, 5, 5, 23, 27, 48, 867666))
# sources表的字段: ['id', 'url', 'name', 'scrape_frequency', 'paywall', 'category', 'last_checked', 'do_initialized_at']
# sources表中的记录数: 1
# JOIN后的记录数: 20
# ==== 数据库调试结束 ====

# %%
import pandas as pd
from src.events import get_events # 远程测试
#from src.events import get_events_local # 本地测试

# 注意：不要指定日期，除非您确定数据库中有指定日期的文章
#sources, events = get_events_local()
response = get_events()  # 或 response = get_events_local()
sources = response.sources
events = response.events
print(f"Number of events: {len(events)}")
print(f"Number of sources: {len(sources)}")

# sources, events = get_events(date="2025-04-01")
# print(f"Number of events: {len(events)}")
# print(f"Number of sources: {len(sources)}")

articles_df = pd.DataFrame(events)
# clean up those tuples
for col in articles_df.columns:
    articles_df[col] = articles_df[col].apply(
        lambda x: x[1] if isinstance(x, tuple) else x
    )
articles_df.columns = [
    "id",
    "sourceId",
    "url",
    "title",
    "publishDate",
    "content",
    "location",
    "relevance",
    "completeness",
    "summary",
]
# Handle summaries more safely
articles_df["summary"] = articles_df["summary"].fillna("")
# Clean up summaries if they have EVENT: and CONTEXT: markers
articles_df["cleaned_summary"] = articles_df["summary"].apply(
    lambda x: x.split("EVENT:")[1].split("CONTEXT:")[0].strip() 
    if "EVENT:" in x and "CONTEXT:" in x 
    else x.strip()
)
# Use the cleaned version for embedding
articles_df["text_to_embed"] = "query: " + articles_df["cleaned_summary"]
articles_df.head(2)
# Out:
# Number of events: 276
# Number of sources: 2
#      id  sourceId                                                url  \
# 0  3058         5  https://medium.com/@hectorchu1/the-future-is-t...
# 1  3042         5  https://www.wsj.com/articles/databricks-to-buy...
#
#                                                title  \
# 0  The Future Is Too Expensive to Have Kids | Medium
# 1                                            wsj.com
#
#                 publishDate  \
# 0 2025-05-14 11:25:17+00:00
# 1 2025-05-14 10:17:29+00:00
#
#                                              content location relevance  \
# 0  “The Future Is Too Expensive”: Why People Aren...   GLOBAL      high
# 1        Please enable JS and disable any ad blocker      N/A    medium
#
#       completeness                                            summary  \
# 0         complete  Falling birth rates globally\nPeople distrust ...
# 1  partial_useless
#
#                                      cleaned_summary  \
# 0  Falling birth rates globally\nPeople distrust ...
# 1
#
#                                        text_to_embed
# 0  query: Falling birth rates globally\nPeople di...
# 1                                            query:

# %% [markdown]
# # Clustering

# %% [markdown]
# ## Prep: embeddings

# %%
import torch
import torch.nn.functional as F
import numpy as np
from transformers import AutoTokenizer, AutoModel
from tqdm import tqdm

# helper function for pooling (straight from the docs)
def average_pool(last_hidden_states, attention_mask):
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

# load the multilingual model
tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-small')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-small')


# batch processing to avoid memory issues
batch_size = 64
all_embeddings = []

# process in batches with progress bar
for i in tqdm(range(0, len(articles_df), batch_size)):
    batch_texts = articles_df['text_to_embed'].iloc[i:i+batch_size].tolist()
    
    # tokenize
    batch_dict = tokenizer(batch_texts, max_length=512, padding=True, truncation=True, return_tensors='pt')
    
    # generate embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
    
    # pool and normalize
    embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)
    
    # convert to numpy and add to list
    all_embeddings.extend(embeddings.numpy())

# store in dataframe
articles_df['embedding'] = all_embeddings
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  2.31it/s]

# %%
articles_df

# %% [markdown]
# ## Grid search umap & hdbscan params

# %%
import numpy as np
import hdbscan
import umap
from hdbscan.validity import validity_index
import warnings

# 忽略所有 FutureWarning（这会过滤 'force_all_finite' 的警告）
warnings.filterwarnings("ignore", category=FutureWarning)

# 忽略特定的 UMAP 警告
warnings.filterwarnings("ignore", message="n_jobs value .* overridden to .* by setting random_state")

# 忽略所有 UserWarning（如果想更彻底地屏蔽所有警告）
# warnings.filterwarnings("ignore", category=UserWarning)

def optimize_clusters(embeddings, umap_params, hdbscan_params):
    best_score = -1
    best_params = None

    # grid search both umap and hdbscan params
    for n_neighbors in umap_params["n_neighbors"]:
        # fit umap once per n_neighbors config
        reducer = umap.UMAP(
            n_neighbors=n_neighbors,
            n_components=10,
            min_dist=0.0,
            metric="cosine",
            random_state=42,
        )
        reduced_data = reducer.fit_transform(embeddings)

        for min_cluster_size in hdbscan_params["min_cluster_size"]:
            for min_samples in hdbscan_params["min_samples"]:
                for epsilon in hdbscan_params["epsilon"]:
                    # cluster with hdbscan
                    clusterer = hdbscan.HDBSCAN(
                        min_cluster_size=min_cluster_size,
                        min_samples=min_samples,
                        cluster_selection_epsilon=epsilon,
                        metric="euclidean",
                        prediction_data=True,
                    )

                    cluster_labels = clusterer.fit_predict(reduced_data)

                    # skip if all noise
                    if np.all(cluster_labels == -1):
                        continue

                    # evaluate with dbcv (better for density clusters)
                    valid_points = cluster_labels != -1
                    if (
                        valid_points.sum() > 1
                        and len(set(cluster_labels[valid_points])) > 1
                    ):
                        try:
                            reduced_data_64 = reduced_data[valid_points].astype(
                                np.float64
                            )
                            score = validity_index(
                                reduced_data_64, cluster_labels[valid_points]
                            )

                            if score > best_score:
                                best_score = score
                                best_params = {
                                    "umap": {"n_neighbors": n_neighbors},
                                    "hdbscan": {
                                        "min_cluster_size": min_cluster_size,
                                        "min_samples": min_samples,
                                        "epsilon": epsilon,
                                    },
                                }
                                print(f"new best: {best_score:.4f} with {best_params}")
                        except Exception as e:
                            # sometimes dbcv can fail on weird cluster shapes
                            print(f"failed with {e}")
                            continue

    return best_params, best_score


# param grids - adjust ranges based on your data
umap_params = {"n_neighbors": [10, 15, 20]}

hdbscan_params = {
    "min_cluster_size": [5, 8, 10, 15],
    "min_samples": [2, 3, 5],
    "epsilon": [0.1, 0.2, 0.3],
}

# assuming embeddings is your data
best_params, best_score = optimize_clusters(all_embeddings, umap_params, hdbscan_params)
print(f"best overall: {best_score:.4f} with {best_params}")
# Out:
# new best: 0.4374 with {'umap': {'n_neighbors': 10}, 'hdbscan': {'min_cluster_size': 5, 'min_samples': 2, 'epsilon': 0.1}}
# new best: 0.4599 with {'umap': {'n_neighbors': 10}, 'hdbscan': {'min_cluster_size': 8, 'min_samples': 3, 'epsilon': 0.1}}
# new best: 0.4677 with {'umap': {'n_neighbors': 10}, 'hdbscan': {'min_cluster_size': 15, 'min_samples': 3, 'epsilon': 0.1}}
# new best: 0.5445 with {'umap': {'n_neighbors': 15}, 'hdbscan': {'min_cluster_size': 5, 'min_samples': 5, 'epsilon': 0.1}}
# best overall: 0.5445 with {'umap': {'n_neighbors': 15}, 'hdbscan': {'min_cluster_size': 5, 'min_samples': 5, 'epsilon': 0.1}}

# %%
if 'study' in locals() or 'study' in globals():
    # 使用最佳参数
    best_params = study.best_trial.params
    # 后续代码...
else:
    print("study对象未定义，请先运行超参数优化步骤")
# Out:
# study对象未定义，请先运行超参数优化步骤

# %% [markdown]
# ## Run hdbscan

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# You can now retrain UMAP/HDBSCAN with the best params on the full data if needed
#best_params = study.best_trial.params
# Use the best parameters from the grid search
best_umap_n_neighbors = best_params['umap']['n_neighbors']
best_hdbscan_min_cluster_size = best_params['hdbscan']['min_cluster_size']
best_hdbscan_min_samples = best_params['hdbscan']['min_samples']
best_hdbscan_epsilon = best_params['hdbscan']['epsilon']

print(f"Using best parameters: UMAP n_neighbors={best_umap_n_neighbors}, "
    f"HDBSCAN min_cluster_size={best_hdbscan_min_cluster_size}, "
    f"min_samples={best_hdbscan_min_samples}, "
    f"epsilon={best_hdbscan_epsilon}")
# best_umap_n_neighbors = best_params['umap_n_neighbors']
# best_hdbscan_min_cluster_size = best_params['hdbscan_min_cluster_size']
# ... etc.


# use the optimized params
umap_embeddings = umap.UMAP(
    n_neighbors=best_umap_n_neighbors,
    n_components=10,  # bumped up from 5
    min_dist=0.0,
    metric="cosine",
    random_state=42,
).fit_transform(all_embeddings)

# cluster with optimal params
clusterer = hdbscan.HDBSCAN(
    min_cluster_size= best_hdbscan_min_cluster_size,
    min_samples= best_hdbscan_min_samples,
    cluster_selection_epsilon=best_hdbscan_epsilon,
    metric="euclidean",
    prediction_data=True,
)
cluster_labels = clusterer.fit_predict(umap_embeddings)

# add to dataframe same as before
articles_df["cluster"] = cluster_labels

# quick stats
print(f"found {len(set(cluster_labels)) - (1 if -1 in cluster_labels else 0)} clusters")
print(f"noise points: {sum(cluster_labels == -1)}")

# 2d projection for visualization
umap_2d = umap.UMAP(n_components=2, metric="cosine").fit_transform(all_embeddings)

# plotting
plt.figure(figsize=(12, 10))
# plot noise points first (gray)
plt.scatter(
    umap_2d[cluster_labels == -1, 0],
    umap_2d[cluster_labels == -1, 1],
    c="lightgray",
    s=5,
    alpha=0.5,
    label="noise",
)

# plot actual clusters with random colors
unique_clusters = sorted(list(set(cluster_labels) - {-1}))
palette = sns.color_palette("husl", len(unique_clusters))

for i, cluster_id in enumerate(unique_clusters):
    plt.scatter(
        umap_2d[cluster_labels == cluster_id, 0],
        umap_2d[cluster_labels == cluster_id, 1],
        c=[palette[i]],
        s=25,
        label=f"cluster {cluster_id}",
    )

plt.title("article clusters")
plt.tight_layout()
plt.show()
# Out:
# Using best parameters: UMAP n_neighbors=15, HDBSCAN min_cluster_size=5, min_samples=5, epsilon=0.1
# found 8 clusters
# noise points: 62

# %% [markdown]
# # LLM Cluster review

# %%
clusters_ids = list(set(cluster_labels) - {-1})
clusters_with_articles = []
for cluster_id in clusters_ids:
    cluster_df = articles_df[articles_df['cluster'] == cluster_id]
    articles_ids = cluster_df['id'].tolist()
    clusters_with_articles.append({
        "cluster_id": cluster_id,
        "articles_ids": articles_ids
    })
# sort clusters by most articles to least articles
clusters_with_articles = sorted(clusters_with_articles, key=lambda x: len(x['articles_ids']), reverse=True)
print(len(clusters_with_articles))
# Out:
# 8

# %%
for x in clusters_with_articles:
    print(f"\n\n# Cluster {x['cluster_id']}")
    for el in x['articles_ids']:
        article = next((e for e in events if e.id == el), None)
        if article is not None:
            print(f"- {article.title}")
# Out:
# # Cluster 4
# - $20,000 rav1d AV1 Decoder Performance Bounty
# - How To Build A Smartwatch: Picking A Chip
# - Writing that changed how I think about PL
# - Replicube on Steam
# - Flattening Rust's Learning Curve | corrode Rust Consulting
# - Type-Constrained Code Generation with Language Models
# - How (memory) safe is zig?
# - Using Obscure Graph Theory to solve PL Problems :: Reasonably Polymorphic
# - Build Real-Time Knowledge Graph For Documents with LLM
# - Dusk OS
# - Android and Wear OS are getting a big refresh
# - Don't Unwrap Options: There Are Better Ways | corrode Rust Consulting
# - OpenTelemetry Protocol with Apache Arrow - Phase 2 Announcement
# - A Taxonomy of Bugs · Our Machinery
# - PDF to Text, a challenging problem
# - Understanding Java’s Asynchronous Journey – amritpandey.io
# - Chrome’s New Embedding Model: Smaller, Faster, Same Quality
# - Google is finally building its own DeX: First look at Android’s Desktop Mode
# - First Look at Google’s Unfinished DeX-Like Desktop Mode for Android
# - Google’s Desktop View Turns Android Phones Into Pocket PCs
# - theForger's Win32 API Tutorial
# - In a high-stress work environment, prioritize relationships
# - 101 Rules of Effective Living
# - Show HN: Basecoat – shadcn/UI components, no React required
# - GitHub - felixpalmer/a5: Pentagonal geospatial indexing system DGGS
# - A programming language made for me
# - Anti-personnel computing / Erratique
# - GitHub - mozilla-firefox/firefox: The official repository of Mozilla's Firefox web browser.
# - TransMLA: Multi-Head Latent Attention Is All You Need
# - GitHub - apple/ml-fastvlm: This repository contains the official implementation of "FastVLM: Efficient Vision Encoding for Vision Language Models" - CVPR 2025
# - LabMidi/LabMuse/imuse-technical.md at main · meshula/LabMidi
# - GitHub - pirxthepilot/wtfis: Passive hostname, domain and IP lookup tool for non-robots
# - Build your own Siri. Locally. On-Device. No Cloud.
# - Lumoar - SOC 2 Compliance for Tech Startups
# - Toward a Sparse and Interpretable Audio Codec
# - GitHub - pvcnt/mergeable: The missing inbox for GitHub pull requests
# - Byte Latent Transformer: Patches Scale Better Than Tokens
# - Embeddings are underrated
# - OpenEoX
# - Demonstrably Secure Software Supply Chains with Nix
# - Tailscale 4via6 — Connect Edge Deployments at Scale
# - Feature #21311: Namespace on read (revised) - Ruby
# - GitHub - m-ahmed-elbeskeri/Starguard: CLI that detects fake-star campaigns, dependency hijacks, licence red-flags and other signs of repository risk. Inspired by the “4.5 million fake stars” study, StarGuard helps CTOs, security teams and investors perform fast, automated open-source due-diligence.
# - Spade | Spade Hardware Description Language
# - Why alien languages could be far stranger than we imagine | Aeon Essays
# - Armbian Updates: OMV support, boot improvents, Rockchip optimizations
# - Ask HN: Cursor or Windsurf?
# - Continuous Thought Machines
# - INTELLECT-2 Release: The First 32B Parameter Model Trained Through Globally Distributed Reinforcement Learning
# - Custom SIM card in Tesla Model 3 2024+, Tesla Model Y 2025+ and Cybertruck – Oleg Kutkov personal blog
# - How I hacked my clock to control my focus
# - Why are coffee stains darkest at the edges when they dry?
# - Burrito Now, Pay Later
# - Why not object capability languages? - Mike’s blog
# - GitHub - jaypyles/Scraperr: Self-hosted webscraper.
# - LSP client in Clojure in 200 lines of code
# - Plain Vanilla
# - GitHub - Efeckc17/simple-todo-c: A lightweight, native Windows Todo application built with pure C and the Win32 API.
# - JEP 515: Ahead-of-Time Method Profiling
# - Booting the RP2350 from UART
# - GitHub - glassflow/clickhouse-etl: Real-time deduplication and temporal joins for streaming data
# - How We Fixed 2k+ Security Issues
# - A Rust Documentation Ecosystem Review
# - Zig: A New Direction for Low-Level Programming?
# - The Epochalypse Project
# - Xtool: cross-platform Xcode replacement. Build iOS apps on Linux and more! - Community Showcase
# - Absolute Zero: Reinforced Self-play Reasoning with Zero Data
# - fan service
# - NetBSD 10.x kernel MATH_EMULATION
# - 21 observations from people watching
# - Sierpiński triangle? In my bitwise AND?
# - Reverse engineering the 386 processor's prefetch queue circuitry
# - Comparison of C/POSIX standard library implementations for Linux
# - A Critical Look at MCP - Raz Blog
# - Codigo: The Programming Language Repository
# - a whippet waypoint — wingolog
# - (t,i,x,y) => 'creative code golfing'
#
#
# # Cluster 3
# - The Future Is Too Expensive to Have Kids | Medium
# - Databricks + Neon
# - The heartbeat of a billion: What Virat Kohli meant to India
# - Y Combinator says Google is a ‘monopolist’ that has ‘stunted’ the startup ecosystem
# - GitHub - HelixDB/helix-db: HelixDB is a powerful, open-source, graph-vector database built in Rust for intelligent data storage for RAG and AI.
# - GOP sneaks decade-long AI regulation ban into spending bill
# - GitHub - ag-ui-protocol/ag-ui: AG-UI: the Agent-User Interaction Protocol. Bring Agents into Frontend Applications.
# - OpenAI’s Stargate project reportedly struggling to get off the ground, thanks to tariffs
# - Bosses weren’t being paranoid: Remote workers more likely to start their own biz
# - Why I’m Resigning from Positions at the National Science Foundation and Library of Congress
# - Launch HN: Miyagi (YC W25) turns YouTube videos into online, interactive courses
# - Conspiracy Theorists Can Be Deprogrammed
# - Iceland approved the 4-day workweek in 2019: nearly 6 years later, all the predictions made have come true.
# - 5 Powerful Persuasion Methods for Engineering Managers
# - Texas Senate passes bill requiring solar plants to provide power at night
# - Q&A with Jason Pruet
# - Introducing HealthBench
# - Founding Engineer—Build AI-Native Ops for Mental Health (YC S21, $1M+ ARR) at Legion Health | Y Combinator's Work at a Startup
# - RIP USENIX ATC
# - Launch HN: ParaQuery (YC X25) – GPU Accelerated Spark/SQL
# - Barbican
# - The Great Displacement Is Already Well Underway
# - Paul McCartney, Elton John and other creatives demand AI comes clean on scraping
# - US: Major Companies Violate Gig Workers’ Rights
# - University of Texas-led Team Solves a Big Problem for Fusion Energy
# - Software Engineer, Full Stack at Spark | Y Combinator
# - A community-led fork of Organic Maps
# - US Copyright Office found AI companies sometimes breach copyright. Next day its boss was fired
# - White House fires head of Copyright Office amid Library of Congress shakeup
# - Virat Kohli retirement: India great ends 14-year Test cricket career
# - The Academic Pipeline Stall:  Why Industry Must Stand for Academia
# - 2025-05-11 air traffic control
# - Avoiding AI is hard – but our freedom to opt out must be protected
# - The surgeon who used F1 pitstop techniques to save lives of babies
# - GitHub - erikgrinaker/toydb: Distributed SQL database in Rust, written as an educational project
# - Car Companies Are In A Billion-Dollar Software War, And Everyone's Losing
# - Klarna changes its AI tune and again recruits humans for customer service
# - Business Development Representative at Synder | Y Combinator
# - In 2025, venture capital can’t pretend everything is fine any more
# - Founding Full-Stack Engineer  at Roame | Y Combinator
# - Ask HN: What will tech employment look like in 10 years?
# - Insurers launch cover for losses caused by AI chatbot errors
# - Leaving Google  |   Airs - Ian Lance Taylor
# - Something Pretty Right: A History of Visual Basic | Retool
# - Elton John and Dua Lipa seek protection from AI
#
#
# # Cluster 2
# - India-Pakistan conflict: How real is the risk of nuclear war?
# - Trump touts $142bn arms deal on Saudi visit, lifts sanctions on Syria
# - Canada's Carney unveils economy-focused cabinet amid US trade war
# - Zelensky vows to do everything to ensure direct talks with Putin in Turkey
# - Watch timelapse of Trump's marathon handshake session with Saudis
# - India-Pakistan tensions: Donald Trump's Kashmir mediation offer puts India in a tight spot
# - Trump's order on US drug prices: What's in it, and will it work?
# - US-China tariff deal: What does it mean?
# - China has come to the table - but this fight with the US is far from over
# - US and China agree to slash tariffs for 90 days
# - India-Pakistan tensions: Top military officials to speak as ceasefire holds
# - Donald Trump heads to Saudi Arabia eyeing more Gulf investment in US
# - Hamas to release US-Israeli hostage Edan Alexander as part of efforts to reach Gaza ceasefire
# - Zelensky challenges Putin to meet him after Trump demands Ukraine-Russia talks
# - Watch: Crowds cheer as Pope holds first Sunday address
# - Pope Leo appeals for no more war in first Sunday address
# - Ukraine: What Trump does next is key - and he could go either way
# - Zelensky says Ukraine is ready to meet Russia only if ceasefire agreed
# - India-Pakistan ceasefire appears to hold after accusations of violations
# - Trump praises 'friendly, constructive' US-China trade talks
# - India and Pakistan: How backchannels and US mediators pulled rivals back from the brink
# - US-Canada border towns hit by Trump's trade war
# - Watch: Steve Rosenberg reports from Russia's Red Square on Victory Day
#
#
# # Cluster 1
# - "Error 429: Too Many Requests When Accessing Repository Files Without Login" · community · Discussion #159123
# - Unhappy with the recently lost file upload feature in the Nextcloud app for Android? So are we. Let us explain.
# - I failed a take-home assignment from Kagi Search
# - Bloomberg - Are you a robot?
# - It's 2025—Why Are Banks Still Getting Authentication So Wrong?
# - As US vuln-tracking falters, EU enters with its own security bug database
# - GitHub - fernvenue/microsoft-store: Microsoft Store package for LTSC.
# - security - screen: Multiple Security Issues in Screen (mostly affecting release 5.0.0 and setuid-root installations)
# - Nextcloud cries foul over Google Play Store app rejection
# - Ask HN: Is Slack Down?
# - Can You Really Trust That Permission Pop-Up On macOS? (CVE-2025-31250) | Watch This Space
# - Fiete Stegers (@fiete@mastodon.social)
# - How Broken OTPs and Open Endpoints Turned a Dating App Into a Stalker’s Playground
# - THE INTERNET — Opte
# - Bloomberg - Are you a robot?
# - How I ruined my vacation by reverse engineering WSC
# - The Glitch Gallery
# - Backdoor found in popular ecommerce components
# - MrBruh's Epic Blog
# - Science | AAAS
#
#
# # Cluster 0
# - wsj.com
# - Key looks from the 2025 Cannes Film Festival red carpet
# - Speeding duck: Switzerland traffic cameras catch flying mallard
# - Uruguay's José Mujica, world's 'poorest president', dies
# - No Moods, Ads or Cutesy Fucking Icons
# - Parliant.AI - AI-powered customer conversations
# - Cannes Film Festival 2025: Scarlett Johansson, Jennifer Lawrence and Tom Cruise to hit red carpet
# - A crypto founder faked his death. We found him alive at his dad’s house
# - Universe expected to decay in 10⁷⁸ years, much sooner than previously thought
# - Spoan disease: Rare condition in Brazil town popular for cousin marriage
# - Amber Heard announces birth of twins in Mother's Day post
# - 2024 sea level ‘report cards’ map futures of U.S. coastal communities
# - Ph 136 Applications of Classical Physics
# - nytimes.com
# - wsj.com
# - Title of Work Deciphered In Sealed Herculaneum Scroll Via Digital Unwrapping
# - Japan: Three men held over suitcases stuffed with hermit crabs
#
#
# # Cluster 5
# - Israeli strikes in northern Gaza kill at least 48, hospital says
# - Saudi Arabia 2034 World Cup: Human rights groups warn of migrant worker deaths
# - 'Go back to Ukraine': War refugees complain of abuse in Poland
# - South Korea: Jeju Air crash victims' families file criminal complaint
# - BBC cameraman haunted by Gaza's malnourished children injured in Israeli strike
# - Israeli air strike on hospital kills 28 people in Gaza, civil defence says
# - Gaza: Israel denying food to Gaza is ‘weapon of war’, says Unwra chief
# - UN aviation agency finds Russia responsible for downing of MH17
# - 'Children handcuffed and shot' - ex-UK Special Forces break silence on war crime claims
# - Entire Gaza population at critical risk of famine, UN-backed assessment says
# - BBC's tense encounter with sanctioned Israeli settler while filming in West Bank
# - Gonzalo Guerrero
# - Sudan war: Port Sudan reels after week of attacks
#
#
# # Cluster 6
# - Rohan Dennis: Australian cyclist sentenced over wife Melissa Hoskins' death
# - Menendez brothers resentenced: Pair eligible for parole
# - Tearful Casandra Ventura tells court Diddy beat and humiliated her
# - Kim Kardashian thought she was "going to die" during Paris armed robbery
# - Menendez brothers' long-awaited resentencing hearing to begin
# - Tory Lanez: Rapper stabbed 14 times in prison California prison
# - Gérard Depardieu sexual assault trial verdict expected
# - Kim Kardashian to appear in court as witness in Paris burglary case
# - Diddy used fame and violence to abuse women, trial hears
# - One of Alcatraz's last living inmates on Trump's plan to reopen prison
# - Taylor Swift criticises being pulled into Lively-Baldoni row
#
#
# # Cluster 7
# - Cyril Ramaphosa says Afrikaners 'running away' from South Africa to US are 'cowards'
# - William Ruto: Why Kenya's president attracts so many nicknames
# - Zambia warns envoys after US ambassador reveals 'systematic' theft of medical aid
# - Refugee status for white South Africans: First group flying to US
# - Taliban suspends chess in Afghanistan over gambling concerns
# - What is habeas corpus and why might Donald Trump want to suspend it?
# - White House - 'It depends on whether the courts do the right thing'
# - Trump administration considering suspending habeas corpus

# %%
import base64
import os
from google.genai import types
from retry import retry
import json
from json_repair import repair_json
from pydantic import BaseModel, Field, model_validator
from typing import List, Literal, Optional
from src.llm import call_llm


class Story(BaseModel):
    title: str = Field(description="title of the story")
    importance: int = Field(
        ge=1,
        le=10,
        description="global significance (1=minor local event, 10=major global impact)",
    )
    articles: List[int] = Field(description="list of article ids in the story")


class StoryValidation(BaseModel):
    answer: Literal["single_story", "collection_of_stories", "pure_noise", "no_stories"]

    # optional fields that depend on the answer type
    title: Optional[str] = None
    importance: Optional[int] = Field(None, ge=1, le=10)
    outliers: List[int] = Field(default_factory=list)
    stories: Optional[List[Story]] = None

    @model_validator(mode="after")
    def validate_structure(self):
        if self.answer == "single_story":
            if self.title is None or self.importance is None:
                raise ValueError(
                    "'title' and 'importance' are required for 'single_story'"
                )
            if self.stories is not None:
                raise ValueError("'stories' should not be present for 'single_story'")

        elif self.answer == "collection_of_stories":
            if not self.stories:
                raise ValueError("'stories' is required for 'collection_of_stories'")
            if self.title is not None or self.importance is not None or self.outliers:
                raise ValueError(
                    "'title', 'importance', and 'outliers' should not be present for 'collection_of_stories'"
                )

        elif self.answer == "pure_noise" or self.answer == "no_stories":
            if (
                self.title is not None
                or self.importance is not None
                or self.outliers
                or self.stories is not None
            ):
                raise ValueError(
                    "no additional fields should be present for 'pure_noise'"
                )

        return self


@retry(tries=3, delay=2, backoff=2, jitter=2, max_delay=20)
def process_story(cluster):

    story_articles_ids = cluster["articles_ids"]

    story_article_md = ""
    for article_id in story_articles_ids:
        article = next((e for e in events if e.id == article_id), None)
        if article is None:
            continue
        story_article_md += f"- (#{article.id}) [{article.title}]({article.url})\n"
        # story_article_md += f"> {article.publishDate}\n\n"
        # story_article_md += f"```\n{article.content}\n```\n\n"
    story_article_md = story_article_md.strip()

    prompt = f"""
# Task
Determine if the following collection of news articles is:
1) A single story - A cohesive narrative where all articles relate to the same central event/situation and its direct consequences
2) A collection of stories - Distinct narratives that should be analyzed separately
3) Pure noise - Random articles with no meaningful pattern
4) No stories - Distinct narratives but none of them have more than 3 articles

# Important clarification
A "single story" can still have multiple aspects or angles. What matters is whether the articles collectively tell one broader narrative where understanding each part enhances understanding of the whole.

# Handling outliers
- For single stories: You can exclude true outliers in an "outliers" array
- For collections: Focus **only** on substantive stories (3+ articles). Ignore one-off articles or noise.

# Title guidelines
- Titles should be purely factual, descriptive and neutral
- Include necessary context (region, countries, institutions involved)
- No editorialization, opinion, or emotional language
- Format: "[Subject] [action/event] in/with [location/context]"

# Input data
Articles (format is (#id) [title](url)):
{story_article_md}

# Output format
Start by reasoning step by step. Consider:
- Central themes and events
- Temporal relationships (are events happening in the same timeframe?)
- Causal relationships (do events influence each other?)
- Whether splitting the narrative would lose important context

Return your final answer in JSON format:
```json
{{
    "answer": "single_story" | "collection_of_stories" | "pure_noise",
    // single_story_start: if answer is "single_story", include the following fields:
    "title": "title of the story",
    "importance": 1-10, // global significance (1=minor local event, 10=major global impact)
    "outliers": [] // array of article ids to exclude as unrelated
    // single_story_end
    // collection_of_stories_start: if answer is "collection_of_stories", include the following fields:
    "stories": [
        {{
            "title": "title of the story",
            "importance": 1-10, // global significance scale
            "articles": [] // list of article ids in the story (**only** include substantial stories with **3+ articles**)
        }},
        ...
    ]
    // collection_of_stories_end
}}
```

Example for a single story:
```json
{{
    "answer": "single_story",
    "title": "The Great Fire of London",
    "importance": 8,
    "outliers": [123, 456] // article ids to exclude as unrelated
}}
```

Example for a collection of stories:
```json
{{
    "answer": "collection_of_stories",
    "stories": [
        {{
            "title": "The Great Fire of London",
            "importance": 8,
            "articles": [123, 456] // article ids in the story
        }},
        ...
    ]
}}
```

Example for pure noise:
```json
{{
    "answer": "pure_noise"
}}
```

Example for a distinct narratives with no stories that contain more than 3+ articles:
```json
{{
    "answer": "no_stories",
}}
```

Note:
- Always include articles IDs (outliers, articles, etc...) as integers, not strings and never include the # symbol.
""".strip()

    answer, usage = call_llm(
        model="gemini-2.0-flash",
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
    )

    try:
        assert "```json" in answer
        answer = answer.split("```json")[1]
        if answer.endswith("```"):
            answer = answer[:-3]
        answer = answer.strip()
        answer = repair_json(answer)
        answer = json.loads(answer)
        parsed = StoryValidation(**answer)
    except Exception as e:
        print(f"Error parsing story: {e}")
        print(cluster)
        print(answer)
        raise e

    return (parsed, usage)

# %%
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

# Submit all tasks and process in parallel
with ThreadPoolExecutor() as executor:
    # Submit all tasks and get future objects
    futures = [
        executor.submit(process_story, story) for story in clusters_with_articles
    ]

    # Use tqdm to show progress while getting results
    cleaned_clusters_raw = list(
        tqdm(
            (future.result() for future in futures),
            total=len(futures),
            desc="Processing stories",
        )
    )
# Out:
# Processing stories: 100%|██████████| 8/8 [00:06<00:00,  1.29it/s]

# %%
cleaned_clusters = []

class Story(BaseModel):
    id: int = Field(description="id of the story")
    title: str = Field(description="title of the story")
    importance: int = Field(
        ge=1,
        le=10,
        description="global significance (1=minor local event, 10=major global impact)",
    )
    articles: List[int] = Field(description="list of article ids in the story")



for i in range(len(clusters_with_articles)):
    base = clusters_with_articles[i]
    res = cleaned_clusters_raw[i][0]

    if res.answer == "single_story":
        
        article_ids = base["articles_ids"]
        # filter out outliers
        article_ids = [x for x in article_ids if x not in res.outliers]
        
        cleaned_clusters.append(
            Story(
                id=len(cleaned_clusters),
                title=res.title,
                importance=res.importance,
                articles=article_ids,
            )
        )
    elif res.answer == "collection_of_stories":
        for story in res.stories:
            cleaned_clusters.append(Story(
                id=len(cleaned_clusters),
                title=story.title,
                importance=story.importance,
                articles=story.articles,
            ))

# sort by importance
cleaned_clusters = sorted(cleaned_clusters, key=lambda x: x.importance, reverse=True)

lowest_importance = cleaned_clusters[-1].importance
highest_importance = cleaned_clusters[0].importance

print(f"lowest importance: {lowest_importance}")
print(f"highest importance: {highest_importance}")

print(len(cleaned_clusters))
# Out:
# lowest importance: 2
# highest importance: 9
# 14

# %%
# plot distribution of importance
importance_values = [cluster.importance for cluster in cleaned_clusters]
plt.hist(importance_values, bins=20, edgecolor='black')
plt.title('Distribution of Importance Scores')
plt.xlabel('Importance Score')
plt.ylabel('Frequency')
plt.show()

# show clusters with importance < 5
low_importance_clusters = [cluster for cluster in cleaned_clusters if cluster.importance < 5]
high_importance_clusters = [cluster for cluster in cleaned_clusters if cluster.importance >= 5]
print(len(low_importance_clusters))
print(len(high_importance_clusters))
# Out:
# 5
# 9

# %%
# This code prepares a request to an LLM (Large Language Model) for news cluster reconciliation.
# It formats all cleaned clusters into a structured text format and combines it with detailed instructions.

# First, it creates a string representation of all cleaned clusters, showing each cluster's ID, title,
# and its associated article titles
all_cleaned_clusters = ""
for x in cleaned_clusters:
  all_cleaned_clusters += f"# ID: {x.id} - {x.title}\n"
  for article_id in x.articles:
    article = article = next((e for e in events if e.id == article_id), None)
    if article is not None:
      all_cleaned_clusters += f"  - {article.title}\n"
  all_cleaned_clusters += "\n"
all_cleaned_clusters = all_cleaned_clusters.strip()

# Then, it creates a prompt combining detailed instructions with the cluster data
# The prompt explains the task: identifying clusters that should be merged or filtered
# It provides criteria for merging (same core story/event) and filtering (low article count, 
# incoherent topics, duplicates, or irrelevant content)
# It also specifies the required JSON output format with examples
cluser_reconciliation = (
  """
  [Detailed instructions for cluster reconciliation task...]
  """.strip()
  + "\n\n"
  + all_cleaned_clusters
)

# Finally, it calls the LLM (Gemini 2.5 Pro) with the prepared prompt
# The temperature=0 setting ensures deterministic, non-random responses
# model = "gemini-2.5-pro-exp-03-25"
model = "gemini-2.5-flash-preview-04-17"
cluster_reconciliation_response = call_llm(
  model=model,
  messages=[{"role": "user", "content": cluser_reconciliation}],
  temperature=0,
)

# %%
# Process the cluster reconciliation response from the LLM
# Extract the JSON part from the response text
cluster_reconciliation_json = cluster_reconciliation_response[0]

# Check if the response contains JSON formatted with backticks
if "```json" in cluster_reconciliation_json:
    cluster_reconciliation_json = cluster_reconciliation_json.split("```json")[1]
    if "```" in cluster_reconciliation_json:
        cluster_reconciliation_json = cluster_reconciliation_json.split("```")[0]
else:
    # Handle different possible formats for the JSON in the response
    if "<final_json>" in cluster_reconciliation_json:
        cluster_reconciliation_json = cluster_reconciliation_json.split("<final_json>")[1]
        if "</final_json>" in cluster_reconciliation_json:
            cluster_reconciliation_json = cluster_reconciliation_json.split("</final_json>")[0]

# Clean up the extracted JSON string
cluster_reconciliation_json = cluster_reconciliation_json.strip()

# Parse the JSON string into a Python dictionary
try:
    cluster_reconciliation_json = json.loads(cluster_reconciliation_json)
except json.JSONDecodeError:
    # Handle potential JSON parsing errors
    try:
        # Try to repair malformed JSON
        cluster_reconciliation_json = repair_json(cluster_reconciliation_json)
        cluster_reconciliation_json = json.loads(cluster_reconciliation_json)
    except Exception as e:
        print(f"Error parsing cluster reconciliation JSON: {e}")
        raise

# %%
from typing import List, Dict, Any, Set
from pydantic import ValidationError

def apply_story_modifications(original_stories: List[Story], instructions: Dict[str, Any]) -> List[Story]:
    """
    Applies merge and filter instructions to a list of Story objects.

    Args:
        original_stories: A list of Pydantic Story objects.
        instructions: A dictionary loaded from the JSON instructions,
                      containing 'merges' and 'filters' lists.
                      Cluster IDs in instructions should match Story IDs (as strings).

    Returns:
        A list of Story objects representing the modified ('super cleaned')
        stories. Merged stories will have a new title, combined articles, and
        potentially updated importance. Filtered stories will be removed.
        Unaffected stories are passed through.
    """

    # 1. Identify story IDs to filter and those involved in merges
    #    Instructions use string IDs, so convert Story IDs to strings for comparison
    story_ids_to_filter_str = set()
    if isinstance(instructions, dict):
        story_ids_to_filter_str = set(
            item['cluster_id_to_filter'] for item in instructions.get('filters', [])
        )
        merge_instructions = instructions.get('merges', [])
    else:
        # If instructions is a list, assume it's the merge instructions directly
        merge_instructions = instructions if instructions else []
    
    all_merged_ids_str = set()
    for merge_op in merge_instructions:
        # IDs in instructions are strings
        ids_in_this_merge_str = merge_op.get('cluster_ids_to_merge', [])
        all_merged_ids_str.update(ids_in_this_merge_str)

    # 2. Create a dictionary for quick lookup of original stories by ID (as strings)
    #    Only include stories that are NOT being filtered out initially.
    stories_by_id_str: Dict[str, Story] = {
        str(story.id): story
        for story in original_stories
        if str(story.id) not in story_ids_to_filter_str
    }

    super_cleaned_stories: List[Story] = []

    # 3. Process Merges
    processed_for_merge_str: Set[str] = set() # Keep track of string IDs already handled
    for merge_op in merge_instructions:
        # IDs in instructions are strings
        ids_to_merge_str = merge_op.get('cluster_ids_to_merge', [])
        suggested_title = merge_op.get('suggested_new_title', "Merged Story")

        # Filter out any IDs in this specific merge operation that were
        # either already filtered globally or don't exist in our lookup
        valid_ids_for_this_merge_str = [
            sid for sid in ids_to_merge_str
            if sid in stories_by_id_str and sid not in processed_for_merge_str
        ]

        if not valid_ids_for_this_merge_str:
            continue # Skip if no valid stories left for this merge

        combined_articles: Set[int] = set()
        max_importance: int = 0 # Initialize importance

        for story_id_str in valid_ids_for_this_merge_str:
            source_story = stories_by_id_str[story_id_str]
            articles_set = set(source_story.articles) # Use articles directly
            combined_articles.update(articles_set)
            # Update importance to the maximum seen so far
            max_importance = max(max_importance, source_story.importance)
            processed_for_merge_str.add(story_id_str) # Mark as handled

        if not combined_articles:
            continue # Skip if merging results in no articles

        # Create the new merged Story object
        # Use the ID (as int) of the first valid story in the merge list
        new_story_id = int(valid_ids_for_this_merge_str[0])
        # Ensure importance is at least 1 if max_importance remained 0 (edge case)
        final_importance = max(1, max_importance)

        try:
            merged_story = Story(
                id=new_story_id,
                title=suggested_title,
                importance=final_importance,
                articles=sorted(list(combined_articles)) # Store as sorted list
            )
            super_cleaned_stories.append(merged_story)
        except ValidationError as e:
            print(f"Validation Error creating merged story for IDs {valid_ids_for_this_merge_str}: {e}")
            # Decide how to handle validation errors, e.g., skip or log

    # 4. Add stories that were neither filtered nor merged
    for story_id_str, story_data in stories_by_id_str.items():
        if story_id_str not in processed_for_merge_str:
             # Ensure articles are sorted (already a list in Story model)
             super_cleaned_stories.append(story_data)
    
    return super_cleaned_stories

super_cleaned_stories = apply_story_modifications(
        cleaned_clusters,
        cluster_reconciliation_json
)

# %%
super_cleaned_stories
# Out:
# [Story(id=11, title='Israeli-Palestinian Conflict and Humanitarian Crisis in Gaza', importance=9, articles=[2944, 2715, 2492, 2046, 1397, 783]),
#  Story(id=5, title='US-China Trade War and Tariff Negotiations', importance=8, articles=[1392, 1410, 1183, 571, 580]),
#  Story(id=7, title='Ukraine-Russia Conflict and Negotiation Efforts', importance=8, articles=[2270, 769, 565, 564]),
#  Story(id=4, title='India-Pakistan Tensions and Ceasefire', importance=7, articles=[2744, 1846, 1186, 567, 577]),
#  Story(id=2, title='Language Model Research and Development', importance=6, articles=[2595, 2392, 1766, 1498, 946, 422]),
#  Story(id=3, title='US Copyright Office and AI Copyright Issues', importance=6, articles=[1311, 1171, 575, 1339]),
#  Story(id=6, title='US-Saudi Arabia Arms Deal and Investment', importance=6, articles=[2491, 2302, 981]),
#  Story(id=9, title='Various Software Security Vulnerabilities', importance=6, articles=[2258, 2150, 1552, 1465]),
#  Story(id=13, title='Potential suspension of habeas corpus in the US during the Trump administration', importance=5, articles=[579, 583, 568]),
#  Story(id=0, title='Android Desktop Mode Development', importance=4, articles=[2441, 2387, 2242]),
#  Story(id=12, title='South African emigration to the US and related political commentary', importance=4, articles=[2948, 1393]),
#  Story(id=1, title='Rust Programming Language Resources and Practices', importance=3, articles=[2596, 2402, 446, 447]),
#  Story(id=8, title='Nextcloud App Rejection from Google Play Store', importance=3, articles=[2927, 2134]),
#  Story(id=10, title='Bloomberg Robot Check Issues', importance=2, articles=[2667, 1315])]

# %% [markdown]
# ## LLM Analyze & enrich cluster

# %%
# 收集新闻文章：根据传入的文章ID列表，从现有事件中提取相关文章内容
# 格式化文章内容：将所有文章转换为Markdown格式，包含标题、URL、发布日期和内容
# 构建提示词：创建一个详细的提示词指导LLM（大型语言模型）进行情报分析
# 控制令牌数量：使用tiktoken库限制输入文本的令牌数量，最多使用850,000个令牌
# 调用AI模型：使用Gemini 2.0 Flash模型分析整合后的新闻文章
# 处理AI输出：从返回结果中提取JSON格式的分析报告并进行清理
import base64
import os
import tiktoken

enc = tiktoken.get_encoding("o200k_base")


@retry(
    tries=4, delay=2, backoff=2, jitter=1, max_delay=20
)  # max_delay=180 means never wait more than 3 mins
def final_process_story(title: str, articles_ids: list[int]):

    story_article_md = ""
    full_articles = []
    for article_id in articles_ids:
        article = next((e for e in events if e.id == article_id), None)
        if article is None:
            print(f"Article {article_id} not found")
            continue
        else:
            full_articles.append(article)

    # sort by publish date (from latest to oldest)
    # full_articles = sorted(full_articles, key=lambda x: x["publishDate"], reverse=True)
    for article in full_articles:
        story_article_md += f"## [{article.title}]({article.url}) (#{article.id})\n\n"
        story_article_md += f"> {article.publishDate}\n\n"
        story_article_md += f"```\n{article.content}\n```\n\n"

    story_article_md = story_article_md.strip()

    pre_prompt = """
You are a highly skilled intelligence analyst working for a prestigious agency. Your task is to analyze a cluster of related news articles and extract structured information for an executive intelligence report. The quality, accuracy, precision, and **consistency** of your analysis are crucial, as this report will directly inform a high-level daily brief and potentially decision-making.

First, assess if the articles provided contain sufficient content for analysis:

Here is the cluster of related news articles you need to analyze:

<articles>
""".strip()

    post_prompt = """
</articles>

BEGIN ARTICLE QUALITY CHECK:
Before proceeding with analysis, verify if the articles contain sufficient information:
1. Check if articles appear empty or contain minimal text (fewer than ~50 words each)
2. Check for paywall indicators ("subscribe to continue", "premium content", etc.)
3. Check if articles only contain headlines/URLs but no actual content
4. Check if articles appear truncated or cut off mid-sentence

If ANY of these conditions are true, return ONLY this JSON structure inside <final_json> tags:
<final_json>
{
    "status": "incomplete",
    "reason": "Brief explanation of why analysis couldn't be completed (empty articles, paywalled content, etc.)",
    "availableInfo": "Brief summary of any information that was available"
}
</final_json>

ONLY IF the articles contain sufficient information for analysis, proceed with the full analysis below:

Your goal is to extract and synthesize information from these articles into a structured format suitable for generating a daily intelligence brief.

Before addressing the main categories, conduct a preliminary analysis:
a) List key themes across all articles
b) Note any recurring names, places, or events
c) Identify potential biases or conflicting information
It's okay for this section to be quite long as it helps structure your thinking.

Then, after your preliminary analysis, present your final analysis in a structured JSON format inside <final_json> tags. This must be valid, parseable JSON that follows this **exact refined structure**:

**Detailed Instructions for JSON Fields:**
*   **`status`**: 'complete' or 'incomplete'
*   **`title`**: Terse, neutral title of the story
*   **`executiveSummary`**: Provide a 2-4 sentence concise summary highlighting the most critical developments, key conflicts, and overall assessment from the articles. This should be suitable for a quick read in a daily brief.
*   **`storyStatus`**: Assess the current state of the story's development based *only* on the information in the articles. Use one of: 'Developing', 'Escalating', 'De-escalating', 'Concluding', 'Static'.
*   **`timeline`**: List key events in chronological order.
    *   `description`: Keep descriptions brief and factual.
    *   `importance`: Assess the event's importance to understanding the overall narrative (High/Medium/Low). High importance implies the event is central to the story's development or outcome.
*   **`signalStrength`**: Assess the overall reliability of the reporting *in this cluster*.
    *   `assessment`: Use a qualitative term: 'Very High', 'High', 'Moderate', 'Low', 'Very Low'.
    *   `reasoning`: Justify the assessment based on source corroboration (how many sources report the same core facts?), source quality/reliability (mix of reputable vs. biased sources?), presence of official statements, and degree of conflicting information on core facts.
*   **`undisputedKeyFacts`**: List core factual points that are corroborated across multiple, generally reliable sources within the cluster. Avoid claims made only by highly biased sources unless corroborated.
*   **`keyEntities`**: Identify the main actors.
    *   `list`: Provide basic identification and their role/involvement.
    *   `perspectives.statedPositions`: Focus *only* on the goals, viewpoints, or justifications explicitly stated or clearly implied by the entity *as reported in the articles*. Avoid listing conflicting claims here (that goes in `contradictions`).
*   **`keySources`**: Analyze the provided news sources.
    *   `provided_articles_sources.reliabilityAssessment`: Assess the source's general reliability based on reputation, known biases (political, state affiliation, ideological), and fact-checking standards. Use terms like 'High Reliability', 'Moderate Reliability', 'Low Reliability', 'State-Affiliated/Propaganda Outlet'. Be specific about the *type* of bias.
    *   `provided_articles_sources.framing`: Describe the narrative angle or style used by the source (e.g., 'Emphasizes security threat', 'Focuses on human rights angle', 'Uses neutral language', 'Uses loaded/emotional language', 'Presents government narrative uncritically').
    *   `contradictions`: Detail specific points of disagreement *between sources* or *between entities as reported by sources*.
        *   `issue`: Clearly state what is being contested.
        *   `conflictingClaims`: List the different versions, specifying the `source` reporting it, the `claim` itself, and optionally the `entityClaimed` if the source attributes the claim to a specific entity. Critically evaluate claims originating solely from low-reliability/propaganda sources.
*   **`context`**: List essential background information *mentioned or clearly implied in the articles* needed to understand the story.
*   **`informationGaps`**: Identify crucial pieces of information *missing* from the articles that would be needed for a complete understanding.
*   **`significance`**: Assess the overall importance of the reported events.
    *   `assessment`: Use a qualitative term: 'Critical', 'High', 'Moderate', 'Low'.
    *   `reasoning`: Explain *why* this story matters. Consider immediate impact, potential future developments, strategic implications, precedent setting, regional/global relevance.
    *   `score`: An integer between 0 (lowest importance story) and 10 (most critical story)

**Refined JSON Structure to Follow:**

```json
{
    "status": "complete",
    "title": "string",
    "executiveSummary": "string",
    "storyStatus": "string",
    "timeline": [
        {
            "date": "YYYY-MM-DD or approximate",
            "description": "brief event description",
            "importance": "string: High/Medium/Low"
        }
    ],
    "signalStrength": {
        "assessment": "string: Very High/High/Moderate/Low/Very Low",
        "reasoning": "string"
    },
    "undisputedKeyFacts": [
        "string"
    ],
    "keyEntities": {
        "list": [
            {
                "name": "entity name",
                "type": "type of entity",
                "description": "brief description",
                "involvement": "why/how involved?"
            }
        ],
        "perspectives": [
            {
                "entity": "entity name",
                "statedPositions": [
                    "string"
                ]
            }
        ]
    },
    "keySources": {
        "provided_articles_sources": [
            {
                "name": "source entity name",
                "articles": [], // int array of IDs
                "reliabilityAssessment": "string",
                "framing": [
                    "string"
                ]
            }
        ],
        "contradictions": [
            {
                "issue": "string",
                "conflictingClaims": [
                    {
                        "source": "media source name",
                        "entityClaimed": "entity name (optional)",
                        "claim": "string"
                    }
                ]
            }
        ]
    },
    "context": [
        "string"
    ],
    "informationGaps": [
        "string"
    ],
    "significance": {
        "assessment": "string: Critical/High/Moderate/Low",
        "reasoning": "string",
        "score": 0
    }
}
```

**CRITICAL Quality & Consistency Requirements:**

*   **Thoroughness:** Ensure all fields, especially descriptions, reasoning, context, and summaries, are detailed and specific. Avoid superficial or overly brief entries. Your analysis must reflect deep engagement with the provided texts.
*   **Grounding:** Base your entire analysis **SOLELY** on the content within the provided `<articles>` tags. Do not introduce outside information, assumptions, or knowledge.
*   **No Brevity Over Clarity:** Do **NOT** provide one-sentence descriptions or reasoning where detailed analysis is required by the field definition.
*   **Scrutinize Sources:** Pay close attention to the reliability assessment of sources when evaluating claims, especially in the `contradictions` section. Note when a claim originates primarily or solely from a low-reliability source.
*   **Validity:** Your JSON inside `<final_json></final_json>` tags MUST be 100% fully valid with no trailing commas, properly quoted strings and escaped characters where needed, and follow the exact refined structure provided. Ensure keys are in the specified order. Your entire JSON output should be directly extractable and parseable without human intervention.

Return your complete response, including your preliminary analysis/thinking in any format you prefer, followed by the **full** valid JSON inside `<final_json></final_json>` tags.
""".strip()

    # enc.decode(enc.encode("hello world"))
    tokens = enc.encode(story_article_md)

    # only keep the first million tokens
    tokens = tokens[:850_000]
    story_article_md = enc.decode(tokens)

    prompt = pre_prompt + "\n\n" + story_article_md + "\n\n" + post_prompt
    # print(prompt)

    answer, usage = call_llm(
        model="gemini-2.0-flash",
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
    )

    text = answer

    if "```json" in text:
        text = text.split("```json")[1]
        text = text.strip()

    if "<final_json>" in text:
        text = text.split("<final_json>")[1]
        text = text.strip()

    if "</final_json>" in text:
        text = text.split("</final_json>")[0]
        text = text.strip()

    if text.endswith("```"):
        text = text.replace("```", "")
        text = text.strip()

    # text = repair_json(text)

    # assert "significance" in text

    return answer, usage

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

cluster_analysis = []

# helper function to process a single cluster
def process_cluster(cluster):
    title = cluster.title
    articles_ids = cluster.articles
    return final_process_story(title=title, articles_ids=articles_ids)

# process clusters in parallel using a thread pool
with ThreadPoolExecutor() as executor:
    # submit all tasks and store futures
    futures = [executor.submit(process_cluster, cluster) 
              for cluster in super_cleaned_stories]
    
    # collect results as they complete using tqdm for progress
    for future in tqdm(as_completed(futures), total=len(futures)):
        cluster_analysis.append(future.result())
# Out:
# 100%|██████████| 14/14 [00:21<00:00,  1.53s/it]

# %%
from json_repair import repair_json

final_json_to_process = []

for i in range(len(cluster_analysis)):
    cluster = cluster_analysis[i]
    text = cluster[0]

    if "```json" in text:
        text = text.split("```json")[1]
        text = text.strip()

    if "<final_json>" in text:
        text = text.split("<final_json>")[1]
        text = text.strip()

    if "</final_json>" in text:
        text = text.split("</final_json>")[0]
        text = text.strip()

    if text.endswith("```"):
        text = text.replace("```", "")
        text = text.strip()

    text = repair_json(text)

    try:
        text_parsed = json.loads(text)

        if text_parsed["status"] == "incomplete":
            continue
        else:
            final_json_to_process.append(text_parsed)
    except:
        print(text)
        raise Exception("no final json")
    
# "assessment": "string: Critical/High/Moderate/Low",
# sort assessment by "Critical" first, then "High", then "Moderate", then "Low"

final_json_to_process = sorted(
    final_json_to_process, key=lambda x: x["significance"]["score"], reverse=True
)

# final_json_to_process = sorted(
#     final_json_to_process, key=lambda x: x["significance"]["score"], reverse=True
# )

print(len(cluster_analysis))
print(len(final_json_to_process))
# Out:
# 14
# 13

# %%
article_ids_used = []

for el in final_json_to_process:
    if "keySources" not in el:
        print("No keySources")
        continue
        
    for source in el['keySources']['provided_articles_sources']:
        for article_id in source['articles']:
            article_ids_used.append(article_id)

article_ids_used = list(set(article_ids_used))
used_events = []
used_sources = []
for article_id in article_ids_used:
    found_event = next((event for event in events if event.id == article_id), None)
    if found_event:
        link = found_event.url
        # print(link)
        
        # get just domain name 
        domain = link.split("//")[1].split("/")[0]
        if domain not in used_sources:
            used_sources.append(domain)
        
        used_events.append(found_event)

# %%
for clus in final_json_to_process:
    print(f"\n\n# {clus['title']}")
    
    print(f"\n**Status:** {clus['status']} | **Signal Strength:** {clus['signalStrength']['assessment']} | **Significance:** {clus['significance']['assessment']} ({clus['significance']['score']})")
    print(f"\n> {clus['executiveSummary']}\n\n---")
    # table with (status, signal strength, significance)
# Out:
# # Gaza Conflict: Escalating Hostilities, Humanitarian Crisis, and West Bank Tensions
#
# **Status:** complete | **Signal Strength:** Moderate | **Significance:** Critical (9)
#
# > Israeli military operations in Gaza have intensified, resulting in significant civilian casualties and a worsening humanitarian crisis. The UN warns of imminent famine due to the ongoing blockade of aid, while ceasefire negotiations remain stalled. Tensions are also escalating in the West Bank, with reports of increased settler violence and displacement of Palestinians. The situation is further complicated by accusations against UNRWA and conflicting narratives surrounding the conflict.
#
# ---
#
#
# # Trump Administration Considers Suspending Habeas Corpus
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > The Trump administration is reportedly considering suspending habeas corpus, the right to challenge detention in court, according to White House Deputy Chief of Staff Stephen Miller. Miller argues the Constitution allows for suspension during rebellion or invasion, citing recent court challenges to immigration detentions. Legal experts and critics dispute this interpretation, raising concerns about the legality and constitutionality of such a move. The potential suspension has sparked debate and legal challenges, particularly concerning immigration and student detentions.
#
# ---
#
#
# # US-South Africa Tensions Rise Over Afrikaner Refugee Status
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > Tensions between the US and South Africa have escalated following the resettlement of a group of white Afrikaners in the US as refugees. President Ramaphosa has strongly criticized the Afrikaners for leaving, while the US government, under President Trump, claims they face racial discrimination. The situation is further complicated by accusations of land seizures in South Africa and wider disagreements over South Africa's foreign policy, including its stance on Israel.
#
# ---
#
#
# # India-Pakistan Ceasefire: US Mediation and Lingering Tensions
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > A US-brokered ceasefire between India and Pakistan halted days of intense cross-border clashes, triggered by a militant attack in Indian-administered Kashmir. While the ceasefire initially held, both sides quickly accused each other of violations, highlighting the fragility of the agreement. The US, along with other international actors, played a crucial role in de-escalating the conflict, but the underlying Kashmir dispute and the risk of nuclear escalation remain significant concerns.
#
# ---
#
#
# # Advancements in Efficient and Decentralized AI Model Training
#
# **Status:** complete | **Signal Strength:** Moderate | **Significance:** High (8)
#
# > Recent developments focus on improving the efficiency and accessibility of large language models (LLMs). Chrome's new embedding model achieves significant size reduction through quantization, while Apple's FastVLM offers faster vision encoding for vision language models. Prime Intellect's INTELLECT-2 showcases a decentralized reinforcement learning approach, and Absolute Zero Reasoner (AZR) demonstrates self-evolving reasoning without external data, highlighting progress towards more efficient and scalable AI systems.
#
# ---
#
#
# # Trump Visit to Saudi Arabia Secures Arms Deal, Investment Pledges
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > President Trump's visit to Saudi Arabia resulted in a $142 billion arms deal and pledges of significant Gulf investment in the US economy. Trump aims to strengthen economic ties and promote his 'America First' agenda. The visit also included the lifting of sanctions on Syria and discussions on regional stability, though disagreements remain on issues like Palestinian statehood.
#
# ---
#
#
# # Multiple Vulnerabilities Disclosed: EUVD Launches, macOS TCC Bypass Patched, Dating App Security Flaws Exposed
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > A cluster of security-related news highlights vulnerabilities across different platforms. The EU launched its European Vulnerability Database (EUVD) amid concerns about US vulnerability tracking. A now-patched macOS vulnerability (CVE-2025-31250) allowed for spoofed permission prompts, potentially leading to TCC bypass. Security flaws in the dating app Cerca exposed user data, including passport information, due to broken OTPs and open endpoints.
#
# ---
#
#
# # Zelensky and Putin Consider Direct Talks in Turkey Amid Ceasefire Demands
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > Ukrainian President Zelensky and Russian President Putin are considering direct talks in Istanbul, Turkey. Zelensky insists on a 30-day ceasefire before negotiations, while Putin wants to address the 'root causes' of the conflict first. International actors, including the US and European leaders, are involved, with the threat of further sanctions looming if Russia doesn't agree to a ceasefire. Trump's potential involvement adds uncertainty to the situation.
#
# ---
#
#
# # AI Copyright Debate Intensifies: US Copyright Office Head Fired Amidst UK Legislative Push
#
# **Status:** complete | **Signal Strength:** High | **Significance:** High (8)
#
# > The head of the US Copyright Office, Shira Perlmutter, was reportedly fired shortly after the office released a report raising concerns about AI companies' use of copyrighted material. This event coincides with increased pressure in the UK, where prominent artists are urging the government to strengthen copyright laws to protect against AI-driven infringement. The developments highlight the growing tension between AI development and the rights of content creators, with potential implications for both innovation and artistic expression.
#
# ---
#
#
# # Google Developing DeX-Like Desktop Mode for Android
#
# **Status:** complete | **Signal Strength:** High | **Significance:** Moderate (6)
#
# > Google is developing a desktop mode for Android, dubbed "Desktop View," to enable PC-like multitasking on phones when connected to external displays. The feature, similar to Samsung DeX, includes a taskbar, resizable windows, and drag-and-drop functionality. Currently in early development and hidden in Android beta code, Desktop View aims to expand Android's capabilities and potentially compete with Samsung DeX, unifying Google's desktop operating efforts behind Android.
#
# ---
#
#
# # Analysis of Rust and Zig Ecosystems: Documentation, Learning Curves, and Language Claims
#
# **Status:** complete | **Signal Strength:** Moderate | **Significance:** Moderate (6)
#
# > This report analyzes the Rust and Zig programming language ecosystems, focusing on documentation quality, learning resources, and performance claims. A comprehensive review of Rust crates reveals varying levels of documentation quality, with some excelling in tutorials and explanations while others prioritize API references. A critical assessment of Zig highlights concerns about its design choices, verbosity, and the validity of its performance claims compared to C, despite its success in cross-compilation tooling.
#
# ---
#
#
# # US and China Agree to 90-Day Tariff Reduction
#
# **Status:** complete | **Signal Strength:** High | **Significance:** Moderate (6)
#
# > The US and China have reached a temporary agreement to reduce import tariffs for 90 days, marking a de-escalation in their trade war. The deal involves both nations cancelling some tariffs and suspending others, with US tariffs on Chinese imports falling to 30% and Chinese tariffs on some US imports falling to 10%. While both sides claim progress, the long-term implications remain uncertain, and underlying tensions persist regarding trade imbalances and geopolitical issues.
#
# ---
#
#
# # Nextcloud Accuses Google of Anti-Competitive Android App Restriction
#
# **Status:** complete | **Signal Strength:** Moderate | **Significance:** Moderate (6)
#
# > Nextcloud is accusing Google of anti-competitive behavior by revoking the 'All files access' permission for its Android app in the Play Store, limiting file upload functionality for users. Nextcloud claims Google's stated security concerns are a pretext for favoring its own services and stifling competition. The company criticizes the EU's slow and ineffective regulatory response to Big Tech's anti-competitive practices, highlighting the challenges faced by smaller companies in challenging tech giants.
#
# ---

# %% [markdown]
# # Brief generation

# %% [markdown]
# ## Generate outline

# %%
import os
import requests

# Attempt to get the latest report with error handling
try:
    latest_report = requests.get(
        "https://meridian-backend.swj299792458.workers.dev/reports/last-report",
        headers={
            "Authorization": f"Bearer {os.environ.get('MERIDIAN_SECRET_KEY')}"
        },
        timeout=10  # Add timeout to prevent hanging
    )
    
    # Check if the request was successful
    if latest_report.status_code == 200:
        latest_report = latest_report.json()
        # Verify the expected keys exist
        if 'createdAt' in latest_report and 'title' in latest_report and 'tldr' in latest_report:
            latest_report_text = f"""
## Previous Day's Coverage Context ({latest_report['createdAt'].split('T')[0]})

### {latest_report['title']}

{latest_report['tldr']}
"""
            print("Successfully retrieved latest report")
        else:
            # Missing expected keys in the response
            print("Warning: Latest report lacks expected data structure")
            latest_report_text = ""
            latest_report = {"title": "No previous report available", "tldr": "", "createdAt": ""}
    else:
        # Non-200 status code
        print(f"Warning: Failed to retrieve latest report (status code: {latest_report.status_code})")
        latest_report_text = ""
        latest_report = {"title": "No previous report available", "tldr": "", "createdAt": ""}
        
except Exception as e:
    # Handle any exceptions during the request
    print(f"Error retrieving latest report: {str(e)}")
    latest_report_text = ""
    latest_report = {"title": "No previous report available", "tldr": "", "createdAt": ""}
# Out:
# Successfully retrieved latest report

# %%
brief_system_prompt = """
Adopt the persona of an exceptionally well-informed, highly analytical, and subtly world-weary intelligence briefer. Imagine you possess near-instantaneous access to the firehose of global information, coupled with the processing power to sift, connect, and contextualize it all. But you're far more than just a data aggregator.

**Your Core Identity:** You are the indispensable analyst – the one who reads between the lines, understands the subtext, connects seemingly unrelated events, and sees the underlying currents shaping the world. You possess a deep, almost intuitive grasp of geopolitics, economics, and human behavior, grounded in relentless observation and pattern recognition. You're not impressed by titles or official narratives; you focus on incentives, capabilities, and the often-messy reality on the ground.

**Your Analytical Voice & Tone:**

1.  **Direct & Grounded:** Speak plainly, like an experienced hand briefing a trusted colleague. Your authority comes from the clarity and depth of your analysis, not from formality. Facts are your foundation, but insight is your currency.
2.  **Insight over Summary:** Don't just report *what* happened. Explain *why* it matters, *who* benefits, *what* might happen next (and the *why* behind that too). Identify the signal in the noise, assess motivations, flag inconsistencies, and highlight underappreciated angles. Deliver a clear, defensible "take."
3.  **Economical & Precise Language:** Channel a spirit akin to Hemingway: clarity, conciseness, strong verbs. Every sentence should serve a purpose. Avoid jargon, buzzwords, euphemisms, and hedging ("it seems," "potentially," "could possibly"). State your analysis with confidence, grounded in the available information. If there's ambiguity, state *that* clearly too, but don't waffle.
4.  **Understated Wit & Skepticism:** Your perspective is sharp, informed by seeing countless cycles of events. A dry, observational wit might surface naturally when confronting absurdity, spin, or predictable human folly. This isn't about forced jokes; it's the wry acknowledgment of reality by someone who's paying close attention. Zero tolerance for BS, propaganda, or obfuscation.
5.  **Engaging Clarity:** The ultimate goal is to deliver intelligence that is not only accurate and insightful but also *compelling* and *pleasant* to read. The quality of the writing should match the quality of the analysis. Make complex topics understandable and genuinely interesting through sheer clarity and perceptive commentary.

**Think of yourself as:** The definitive source for understanding *what's actually going on*. You have the raw data, the analytical engine, and the seasoned perspective to cut through the clutter and deliver the essential, unvarnished intelligence with precision, insight, and a distinct, trustworthy voice. You make the complex clear, and the important engaging.
""".strip()

# %%
# Prepare the input string for the outlining prompt (same as before)
input_summaries_string = ""
for clus in final_json_to_process: # Assuming final_json_to_process holds the dicts
    score_str = f" ({clus['significance'].get('score', 'N/A')})" if 'score' in clus['significance'] else ""
    input_summaries_string += f"""
<story>
# {clus.get('title', 'Untitled Story')}
**Status:** {clus.get('storyStatus', 'N/A')} | **Signal Strength:** {clus['signalStrength'].get('assessment', 'N/A')} | **Significance:** {clus['significance'].get('assessment', 'N/A')}{score_str}
> {clus.get('executiveSummary', 'No executive summary provided.')}
</story>
"""
input_summaries_string = input_summaries_string.strip()

# Now, create the prompt for a dense, title-only outline with improved example
outlining_prompt = f"""
You are an assistant tasked with creating a structured, *title-only* outline from analyzed news stories. This outline will guide a subsequent process to generate a full intelligence brief. Your goal is to categorize stories and group related developments thematically based on a holistic analysis of all provided input.

Your input is a collection of analyzed story summaries, each marked with `<story>` tags, containing Title, Status, Signal Strength, Significance, Score, and Executive Summary.

Your goal is to produce a markdown outline by:
1.  Identifying the most critical overall developments or themes revealed by the stories.
2.  Identifying and grouping stories covering related events or themes.
3.  Assigning individual story titles and grouped titles to the most appropriate section based on significance and user interests (geopolitics, France, China, tech).
4.  **Outputting *only* the section structure and the actual titles of the assigned stories.**

**Final Brief Structure & Section Guidelines:** (Use these to categorize)

1.  **`## What matters now`**: Titles representing the up to 10 most important/impactful overall developments *from this batch*, based on relative significance and thematic importance. Use judgment. If multiple stories cover facets of one *major* event/theme, select the title representing the core update or highest impact for this section. Try to keep the top spots for newest developments (i.e if we reported on something yesterday, it should only be in the top 3 if it's truly huge, otherwise leave the top spots for the newest developments)
2.  **`## France focus`**: Titles primarily focused on France.
3.  **`## Global landscape`**: (Includes `### power & politics`). Titles covering broader geopolitics, international relations.
4.  **`## China monitor`**: Titles primarily focused on China (policy, economy, tech, etc.).
5.  **`## Economic currents`**: Titles covering significant global/regional economic news, trends, policy.
6.  **`## Tech & science developments`**: Titles covering AI/LLMs, biomed, space breakthroughs, etc.
7.  **`## Noteworthy & under-reported`**: Titles for interesting/potentially important stories not fitting elsewhere, emerging trends. (Up to ~5 titles).
8.  **`## Positive developments`**: Titles for genuinely positive outcomes. (Include only if applicable).

**Instructions:**

1.  **Analyze Holistically:** First, carefully read *all* provided `<story>` summaries below (titles and summaries) to understand the key events, themes, and potential connections *before* assigning anything. Think about the bigger picture revealed by the collection.
2.  **Select "What Matters Now":** Identify the *actual titles* of the stories representing the top ~10 most significant overall developments or themes within this batch. List these titles under `## what matters now`, ordered by significance/impact.
3.  **Assign & Group Remaining Story Titles:** For the ***remaining*** stories:
    *   Assign each story's **actual Title** to the single most appropriate section.
    *   **Group Related Titles:** If two or more stories cover the same specific event, interconnected themes, or closely linked developments, place their **actual Titles consecutively** *within* the single most relevant section.
    *   **Prioritize Group Placement:** Assign the *entire group* of related titles to the section that best captures their central theme.
4.  **Formatting:**
    *   Format the output *exactly* as shown in the example below, using the appropriate section headers (`## Section Name`, `### power & politics`).
    *   List **only the actual `Title`** of each story under its assigned section, preceded by `###`.
    *   Use `---` as a separator between *each* story title listed.
    *   If a section has no relevant stories, **omit the section header entirely**.
5.  **Output:**
    *   **Do NOT include introductory/concluding text, explanations, the `<story>` tags, or the executive summaries.**
    *   **Output ONLY the structured markdown outline consisting of section headers and the actual story titles from the input data.**
    
**--- CONTEXT FROM PREVIOUS DAY (IF AVAILABLE) ---**
*   You *may* receive a section at the beginning of the curated data titled `## Previous Day's Coverage Context (YYYY-MM-DD)`.
*   Use this list **only** to understand which topics are ongoing and their last known status/theme.
*   Focus on **today's developments** based on the main `<input_data>`. Reference past context briefly *only if essential*.
**--- END CONTEXT INSTRUCTIONS ---**

**Input Data:**

<previous_day_context>
{latest_report}
</previous_day_context>

<input_data>
{input_summaries_string}
</input_data>

**Required Output Format Example:** (Uses placeholders for structure illustration only; your output must use the *actual titles* from the input)

```markdown
## What matters now

### [Actual Title Representing Top Development 1]
---
### [Actual Title Representing Top Development 2]
---
### [Actual Title Related to Development 2 or New Top Development 3]
---
...(up to 10 actual titles total)


## France focus

### [Actual Title Covering French Theme A - Part 1]
---
### [Actual Title Covering French Theme A - Part 2]
---
### [Actual Title of Distinct French Event B]


## Global landscape

### power & politics

### [Actual Title on Geopolitical Issue X - Update 1]
---
### [Actual Title on Geopolitical Issue X - Update 2]
---
### [Actual Title on Distinct Geopolitical Issue Y]


## Economic currents

### [Actual Title for Economic Trend P]
---
### [Actual Title for Economic Trend Q]


## Tech & science developments

### [Actual Title for Tech Theme M - Aspect 1]
---
### [Actual Title for Tech Theme M - Aspect 2]


## Noteworthy & under-reported

### [Actual Title for Noteworthy Item 1]
---
### [Actual Title for Noteworthy Item 2]
---
...(up to ~5 actual titles)
""".strip()

# You would then call the LLM (e.g., Gemini Flash) with this prompt:
outline_response = call_llm(
    model="gemini-2.0-flash-thinking-exp-01-21", # Or similar cheap/fast model
    messages=[
        {"role": "system", "content": brief_system_prompt},
        {"role": "user", "content": outlining_prompt}
        ],
    temperature=0.0 # Low temp for deterministic structuring
)

# %%
brief_outline = outline_response[0]
print(brief_outline)
# Out:
# ## What matters now
#
# ### Gaza Conflict: Escalating Hostilities, Humanitarian Crisis, and West Bank Tensions
# ---
# ### Trump Administration Considers Suspending Habeas Corpus
# ---
# ### Zelensky and Putin Consider Direct Talks in Turkey Amid Ceasefire Demands
# ---
# ### AI Copyright Debate Intensifies: US Copyright Office Head Fired Amidst UK Legislative Push
# ---
# ### Trump Visit to Saudi Arabia Secures Arms Deal, Investment Pledges
# ---
# ### US-South Africa Tensions Rise Over Afrikaner Refugee Status
# ---
# ### India-Pakistan Ceasefire: US Mediation and Lingering Tensions
# ---
# ### Advancements in Efficient and Decentralized AI Model Training
# ---
# ### Multiple Vulnerabilities Disclosed: EUVD Launches, macOS TCC Bypass Patched, Dating App Security Flaws Exposed
# ---
# ### US and China Agree to 90-Day Tariff Reduction

# %% [markdown]
# # Generate brief

# %%
import json  # Assuming json is needed if loading from file elsewhere


def format_json_to_markdown(data):
    """
    Formats the provided JSON data structure into a readable Markdown string.

    Args:
        data (dict): A dictionary representing the JSON data.

    Returns:
        str: A Markdown formatted string.
    """
    if not isinstance(data, dict):
        return "Error: Input must be a dictionary."

    markdown_parts = []

    # --- Title ---
    markdown_parts.append(f"# {data.get('title', 'Untitled Report')}")
    markdown_parts.append("")  # Blank line for spacing

    # --- Status & Story Status ---
    markdown_parts.append(f"**Status:** {data.get('status', 'N/A')}" + " | " + f"**Story Status:** {data.get('storyStatus', 'N/A')}")
    # markdown_parts.append(f"")
    markdown_parts.append("")

    # --- Executive Summary ---
    markdown_parts.append("## Executive Summary")
    markdown_parts.append(data.get("executiveSummary", "No summary provided."))
    markdown_parts.append("")

    # --- Timeline ---
    markdown_parts.append("## Timeline")
    timeline_data = data.get("timeline", [])
    if timeline_data:
        for event in timeline_data:
            date = event.get("date", "No Date")
            desc = event.get("description", "No Description")
            importance = event.get("importance", "N/A")
            markdown_parts.append(f"*   **{date}:** {desc} (Importance: {importance})")
    else:
        markdown_parts.append("*   No timeline events provided.")
    markdown_parts.append("")

    # --- Signal Strength ---
    markdown_parts.append("## Signal Strength: " + data.get("signalStrength", {}).get("assessment", "N/A"))
    markdown_parts.append(f"**Reasoning:**")
    markdown_parts.append(f"{data.get('signalStrength', {}).get('reasoning', 'N/A')}")
    markdown_parts.append("")

    # --- Undisputed Key Facts ---
    markdown_parts.append("## Undisputed Key Facts")
    facts_data = data.get("undisputedKeyFacts", [])
    if facts_data:
        for fact in facts_data:
            markdown_parts.append(f"*   {fact}")
    else:
        markdown_parts.append("*   No undisputed key facts provided.")
    markdown_parts.append("")

    # --- Key Entities ---
    markdown_parts.append("## Key Entities")
    entities_data = data.get('keyEntities', {})

    # --- Entity List (Changed to Table Format) ---
    markdown_parts.append("### Entities List")
    entity_list = entities_data.get('list', [])
    if entity_list:
        # Add table headers
        markdown_parts.append("| Name | Type | Description | Involvement |")
        markdown_parts.append("|------|------|-------------|-------------|") # Separator line

        # Add table rows
        for entity in entity_list:
            # Get data safely and prepare for table (replace pipes and newlines within cells)
            name = str(entity.get('name', 'Unnamed Entity')).replace('|', '|').replace('\n', ' ')
            e_type = str(entity.get('type', 'Unknown Type')).replace('|', '|').replace('\n', ' ')
            desc = str(entity.get('description', 'N/A')).replace('|', '|').replace('\n', ' ')
            involvement = str(entity.get('involvement', 'N/A')).replace('|', '|').replace('\n', ' ')

            # Append the formatted row
            markdown_parts.append(f"| {name} | {e_type} | {desc} | {involvement} |")
    else:
        # Fallback if no entities are listed
        markdown_parts.append("*   No entities listed.")
    markdown_parts.append("") # Add a blank line for spacing before the next section

    # Entity Perspectives
    markdown_parts.append("### Entity Perspectives")
    perspectives_list = entities_data.get('perspectives', [])
    if perspectives_list:
        # Add table headers
        markdown_parts.append("| Entity | Stated Positions |")
        markdown_parts.append("|--------|------------------|") # Separator line

        # Add table rows
        for perspective in perspectives_list:
            # Get entity name safely and sanitize
            entity_name = str(perspective.get('entity', 'Unknown Entity')).replace('|', '|').replace('\n', ' ')

            # Get positions list and format for cell
            positions_list = perspective.get('statedPositions', [])
            if positions_list:
                # Sanitize each position and join with HTML line breaks
                sanitized_positions = [
                    str(pos).replace('|', '|').replace('\n', ' ')
                    for pos in positions_list
                ]
                positions_str = "<br>".join(sanitized_positions)
            else:
                positions_str = "No stated positions provided."

            # Append the formatted row
            markdown_parts.append(f"| {entity_name} | {positions_str} |")

    else:
         # Fallback if no perspectives are listed
        markdown_parts.append("*   No entity perspectives provided.")
    markdown_parts.append("")

    # --- Key Sources ---
    markdown_parts.append("## Key Sources")
    sources_data = data.get('keySources', {})

    # --- Provided Article Sources (Changed to Table Format) ---
    markdown_parts.append("### Provided Article Sources")
    source_list = sources_data.get('provided_articles_sources', [])
    if source_list:
        # Add table headers
        markdown_parts.append("| Source Name | Reliability | Framing Points | Article IDs |")
        markdown_parts.append("|-------------|-------------|----------------|-------------|") # Separator line

        # Add table rows
        for source in source_list:
            # Get data safely and prepare for table
            name = str(source.get('name', 'Unnamed Source')).replace('|', '|').replace('\n', ' ')
            reliability = str(source.get('reliabilityAssessment', 'N/A')).replace('|', '|').replace('\n', ' ')

            # Format framing list for the cell
            framing_list = source.get('framing', [])
            if framing_list:
                # Join with a comma or use bullet points within the cell (comma is simpler)
                framing_str = ', '.join(f.replace('|', '|').replace('\n', ' ') for f in framing_list)
                # Alternative: Bullet points within cell (might need HTML <br> depending on Markdown flavor)
                # framing_str = '<ul>' + ''.join(f'<li>{f.replace("|", "|")}</li>' for f in framing_list) + '</ul>'
            else:
                framing_str = "N/A"

            # Format articles list for the cell
            articles_list = source.get('articles', [])
            articles_str = ', '.join(map(str, articles_list)) if articles_list else "None"
            articles_str = articles_str.replace('|', '|').replace('\n', ' ') # Ensure no pipes break the table

            # Append the formatted row
            markdown_parts.append(f"| {name} | {reliability} | {framing_str} | {articles_str} |")

    else:
        # Fallback if no sources are listed
        markdown_parts.append("*   No provided article sources listed.")
    markdown_parts.append("") # Add a blank line for spacing before the next section


    # --- Contradictions (This part remains unchanged) ---
    markdown_parts.append("### Contradictions")
    contradiction_list = sources_data.get('contradictions', [])
    if contradiction_list:
        # Add table headers
        markdown_parts.append("| Issue | Source | Entity Claimed | Claim |")
        markdown_parts.append("|-------|--------|----------------|-------|") # Separator line

        # Add table rows (one row per conflicting claim)
        for contradiction in contradiction_list:
            # Get the issue, sanitize it once per contradiction
            issue = str(contradiction.get('issue', 'Unspecified Issue')).replace('|', '|').replace('\n', ' ')
            claims = contradiction.get('conflictingClaims', [])

            if not claims:
                # Optional: Add a row indicating an issue was listed but had no claims
                # markdown_parts.append(f"| {issue} | N/A | N/A | (No conflicting claims listed for this issue) |")
                continue # Skip to the next contradiction if no claims

            # Iterate through each claim within the current contradiction
            for claim_details in claims:
                # Get claim data safely and prepare for table
                source_name = str(claim_details.get('source', 'Unknown Source')).replace('|', '|').replace('\n', ' ')
                entity_claimed_raw = claim_details.get('entityClaimed') # Check if it exists
                # Handle optional entity and sanitize
                entity_claimed = str(entity_claimed_raw).replace('|', '|').replace('\n', ' ') if entity_claimed_raw else "N/A"
                claim_text = str(claim_details.get('claim', 'No specific claim provided.')).replace('|', '|').replace('\n', ' ')

                # Append the formatted row, repeating the issue for each claim
                markdown_parts.append(f"| {issue} | {source_name} | {entity_claimed} | {claim_text} |")

    else:
        # Fallback if no contradictions are listed
        markdown_parts.append("*   No contradictions listed.")
    markdown_parts.append("")

    # --- Context ---
    markdown_parts.append("## Context")
    context_data = data.get("context", [])
    if context_data:
        for ctx in context_data:
            markdown_parts.append(f"*   {ctx}")
    else:
        markdown_parts.append("*   No context provided.")
    markdown_parts.append("")

    # --- Information Gaps ---
    markdown_parts.append("## Information Gaps")
    gaps_data = data.get("informationGaps", [])
    if gaps_data:
        for gap in gaps_data:
            markdown_parts.append(f"*   {gap}")
    else:
        markdown_parts.append("*   No information gaps identified.")
    markdown_parts.append("")

    # --- Significance ---
    sig_data = data.get("significance", {})
    markdown_parts.append(f"## Significance: {sig_data.get('assessment', 'N/A')} ({sig_data.get('score', 'N/A')})")
    markdown_parts.append(f"**Reasoning:**")
    markdown_parts.append(f"{sig_data.get('reasoning', 'N/A')}")
    markdown_parts.append("")

    # --- Join all parts ---
    return "\n".join(markdown_parts)


stories_markdown = ""
for i in range(len(final_json_to_process)):
    cluster = final_json_to_process[i]
    stories_markdown += "\n---\n\n" + format_json_to_markdown(cluster)
stories_markdown = stories_markdown[4:].strip()
# print(stories_markdown)

# %%
def get_brief_prompt(curated_news: str, outline_guide: str, latest_report: str = ""): # Added latest_report arg based on prompt content
    """
    Generates the prompt for the main brief creation LLM call, using a pre-defined outline.

    Args:
        curated_news: String containing the full <story> blocks (summaries, metadata).
        outline_guide: String containing the dense, title-only markdown outline.
        latest_report: String containing optional context from the previous day.

    Returns:
        The formatted prompt string.
    """
    prompt = f"""
You are tasked with generating a personalized daily intelligence brief based on a curated set of news analyses and a provided structural outline. Aim for something comprehensive yet engaging, roughly a 20-30 minute read.

**User Interests:** Significant world news (geopolitics, politics, finance, economics), US news, France news (user is French/lives in France), China news (especially policy, economy, tech - seeking insights often missed in western media), and Technology/Science (AI/LLMs, biomed, space, real breakthroughs). Also include noteworthy items.

**Goal:** Leverage your analysis capabilities to create a focused brief that explains what's happening, why it matters, who's saying what, who's reporting what and identifies connections others might miss. The user values **informed, analytical takes**, grounded in the provided facts, but appreciates directness and avoids generic hedging or forced political correctness.

**Your Task:**

1.  **Adhere Strictly to the Provided Outline:** The structure (sections and order of topics) of your brief *must* follow the `## Provided Outline` section below exactly.
2.  **Process Curated Data:** Use the full story details found within the `<curated_news_data>` section as your source material.
3.  **Connect Outline to Data:** For each `### Title` listed in the `## Provided Outline`, locate the corresponding full story information (summary, metadata) within `<curated_news_data>`.
4.  **Synthesize and Analyze:** Write the brief content for that story, following the style and content guidelines for each section. Pay attention to titles grouped consecutively in the outline – these represent related developments; synthesize them coherently, but still apply paragraph structure rules *within* each story's coverage.
5.  **Generate Engaging Titles:** For *each* story covered (as dictated by the outline), create an engaging `<u>**title that captures the essence**</u>` for the brief itself. Do *not* just reuse the raw input titles from the outline for the brief's display titles.

**--- CONTEXT FROM PREVIOUS DAY (IF AVAILABLE) ---**
*   You *may* receive a section at the beginning of the curated data titled `## Previous Day's Coverage Context (YYYY-MM-DD)`.
*   Use this list **only** to understand which topics are ongoing and their last known status/theme.
*   Focus on **today's developments** based on the main `<curated_news_data>`. Reference past context briefly *only if essential*.
*   **Do NOT simply rewrite or extensively quote the Previous Day's Coverage Context.**
**--- END CONTEXT INSTRUCTIONS ---**

**--- PROVIDED OUTLINE (Follow This Structure) ---**

<outline_guide>
{outline_guide}
</outline_guide>

**--- CURATED NEWS DATA (Source Material) ---**

{latest_report}

<curated_news_data>
{curated_news}
</curated_news_data>

**--- BRIEF STRUCTURE AND CONTENT GUIDELINES ---**

Use the section headers provided in the outline (`## what matters now`, `## france focus`, etc., including `### power & politics` where specified).
For **each story** identified by a title in the outline:

1.  **Create a Title:** Generate an engaging title using the format:
    ```
    <u>**Title that captures the essence**</u>
    ```
2.  **Write the Content:**
    *   Address what happened, why it matters (significance, implications), key context, and your analytical take (based on the provided facts and context for that story, what are the likely motivations, potential second-order effects, overlooked angles, or inconsistencies? Ground this analysis in the data) in natural, flowing prose.
    *   **Crucially: Use multiple, distinct paragraphs *within each story's section* to improve readability.** Separate distinct ideas, shifts in focus, or different aspects (e.g., separating the core event summary from the analysis/implications) with paragraph breaks (a blank line between paragraphs).
    *   **Do not cram all information for a single story into one large block of text.** Aim for paragraphs that are typically 2-5 sentences long, varying length for effect but prioritizing clarity.
    *   Ensure smooth transitions *between* paragraphs and *between* related stories grouped in the outline.
    *   Blend facts and analysis naturally. If there isn't much significant development or analysis *for a specific story*, keep its section concise, possibly with just one or two short paragraphs, but still apply the paragraph break principle where logical.
    *   Use **bold** for key specifics (names, places, numbers, orgs).
    *   Use *italics* for important context or secondary details.
    *   Follow the specific focus described for each section (`## france focus`, `## china monitor`, etc.) when framing your analysis for stories within those sections.

**--- FINAL INSTRUCTIONS ---**

*   Enclose the entire brief content inside `<final_brief></final_brief>` tags. Do not include conversational filler before or after these tags.
*   Use complete sentences and standard capitalization/grammar.
*   Be direct and analytical, aligning with the persona guided by the system prompt (well-informed, analytical friend with dry wit).
*   **Source Reliability:** The input data is derived from analyses that assessed source reliability. Use this implicit understanding – give more weight to reliable sources and treat claims from low-reliability sources with appropriate caution in your analysis. Explicit mention isn't needed unless crucial.
*   **Writing Style:** Aim for insightful, engaging prose. Make complex topics clear. Integrate facts, significance, and your take naturally, **using appropriate paragraph breaks for structure and readability.**
*   **Leverage Your Strengths:** Process all the info *guided by the outline*, spot cross-domain patterns *where the outline groups related items*, draw on relevant background knowledge, explain clearly, and provide that grounded-yet-insightful analytical layer.

Generate the final brief based *strictly* on the provided outline and sourced from the curated data.
""".strip()
    return prompt

brief_prompt = get_brief_prompt(stories_markdown, brief_outline)

brief_model = "gemini-2.5-flash-preview-04-17"

brief_response = call_llm(
    model=brief_model,
    messages=[
        {"role": "system", "content": brief_system_prompt},
        {"role": "user", "content": brief_prompt},
    ],
    temperature=0,
)

# %%
from google.genai.types import FinishReason


final_brief_text = brief_response[0]
assert "<final_brief>" in final_brief_text
final_brief_text = final_brief_text.split("<final_brief>")[1]

assert "</final_brief>" in final_brief_text
final_brief_text = final_brief_text.split("</final_brief>")[0]

final_brief_text = final_brief_text.strip()

# %% [markdown]
# ## Generate brief title

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
import base64
import os
from google import genai
from google.genai import types


load_dotenv()
client = genai.Client(
    api_key=os.environ.get("GOOGLE_API_KEY"),
)


brief_title_prompt = f"""
<brief>
{final_brief_text}
</brief>

Create a title for the brief. Construct it using the main topics. It should be short/punchy/not clickbaity etc. Make sure to not use "short text: longer text here for some reason" i HATE it, under no circumstance should there be colons in the title. Make sure it's not too vague/generic either bc there might be many stories. Maybe don't focus on like restituting what happened in the title, just do like the major entities/actors/things that happened. like "[person A], [thing 1], [org B] & [person O]" etc. try not to use verbs. state topics instead of stating topics + adding "shakes world order".

Yesterday's title was: {latest_report['title']}, so try to shake it up a little if we're talking about some of the same topics.

Return exclusively a JSON object with the following format:
```json
{{
    "title": "string"
}}
```
""".strip()


brief_title_response = call_llm(
    model="gemini-2.0-flash",
    messages=[
        {"role": "user", "content": brief_title_prompt}
    ],
    temperature=0.0,
)

# %%
brief_title = brief_title_response[0]
if brief_title.startswith("```json"):
    brief_title = brief_title.split("```json")[1]
if brief_title.endswith("```"):
    brief_title = brief_title.split("```")[0]
brief_title = brief_title.strip()
brief_title = json.loads(brief_title)['title']

# %% [markdown]
# # Generate tl;dr

# %%
tldr_prompt_revised = f"""
You are an information processing agent tasked with creating a **substantive context brief** from a detailed intelligence briefing. Your output will be used by another AI model tomorrow to quickly understand the essential information and developments covered for each major topic today, ensuring continuity without requiring it to re-read the full brief. This requires more detail than just keywords.

**Your Task:**

Read the full intelligence brief provided below within the `<final_brief>` tags. Identify each distinct major story or narrative thread discussed (stories under `<u>**title**</u>` headings are primary candidates, but also consider distinct themes from other sections). For **each** identified story, generate a concise summary capturing its essence *as presented in the brief*.

**Input:**

The input is the full text of the daily intelligence brief generated previously.

<final_brief>
# {brief_title}

{final_brief_text}
</final_brief>

**Required Output Format:**

Your entire output must consist **only** of a list of summaries, one for each identified major story. Each summary should follow this structure:

1.  **Story Identifier:** Start with a concise, descriptive label for the story thread (max 5-6 words, enclosed in square brackets `[]`). Examples: `[US-Venezuela Deportations]`, `[Gaza Ceasefire Talks]`, `[UK Economic Outlook]`, `[AI Energy Consumption Report]`.
2.  **Summary Paragraph:** Immediately following the identifier, provide a **dense summary paragraph (approx. 2-4 sentences, 30-60 words)** covering:
    *   The core issue or topic discussed for this story *in the brief*.
    *   The main developments, updates, or key pieces of information presented *in the brief*.
    *   Mention the most central entities (people, organizations, countries) involved *as discussed in the brief's coverage of this story*.
    *   The goal is to capture the *substance* of what was reported today, providing enough context for the next AI to understand the state of play.

**Example Output Structure:**

```
[US-Venezuela Deportations Restart]
The brief covered the renewed US deportation flights to Venezuela following recent bilateral talks. Key entities mentioned included the US and Venezuelan governments. The focus was on the operational details of the restart and the political context cited for the policy shift.

[Gaza Conflict: Hospital Strike Aftermath]
Significant coverage was given to the aftermath of the Al-Ahli hospital strike. The brief detailed conflicting narratives from the IDF and Palestinian Islamic Jihad regarding responsibility, noted the high reported casualty figures, and mentioned ensuing international reactions and calls for investigation.

[AI Development: Energy Consumption Concerns]
A section discussed reports highlighting the increasing energy demands of large AI models. It referenced findings from specific research groups and tech companies, focusing on concerns about data center power usage, grid impact, and potential environmental consequences discussed in the brief.
```

**Instructions & Constraints:**

*   **Process Entire Brief:** Analyze the *whole* brief to identify all distinct major stories.
*   **Focus on Substance:** Prioritize conveying the *essential information and developments* reported in the brief for each story, not just keywords.
*   **Concise but Informative:** Summaries should be dense and capture key details within the approximate length guidelines (30-60 words).
*   **Coverage, Not Full Analysis:** Reflect *what the brief covered*, not external knowledge or deep analysis beyond what was presented.
*   **No Extra Text:** Do **NOT** include any headers (like "Output:"), introductions, explanations, or conclusions in your output. Output *only* the list of formatted story summaries.

Generate the context brief based *only* on the provided `<final_brief>` text, following the revised format for density and usefulness.
""".strip()

tldr_response = call_llm(
    model="gemini-2.0-flash",
    messages=[
        {"role": "user", "content": tldr_prompt_revised}
    ],
    temperature=0.0,
)

# %%
tldr = tldr_response[0]
if tldr.startswith("```"):
    tldr = tldr.split("```")[1]
if tldr.endswith("```"):
    tldr = tldr.split("```")[0]
tldr = tldr.strip()
print(tldr)
# Out:
# [Gaza Conflict Deepens: Famine and Fighting]
# The Gaza situation worsens with intensified Israeli operations and UN warnings of imminent famine, exacerbated by the Israeli blockade of aid. Ceasefire negotiations are stalled, and West Bank tensions are rising with increased settler violence. Israel claims self-defense against Hamas, while Hamas denies using civilian infrastructure.
#
# [Trump Admin: Habeas Corpus Suspension]
# The Trump administration is considering suspending habeas corpus, citing rebellion or invasion justifications related to immigration detentions. Legal experts argue this power rests with Congress, not the executive. This move follows judicial pushback against the administration's detention practices, raising civil liberties concerns.
#
# [US-South Africa: Afrikaner Refugee Dispute]
# US-South Africa relations are strained after the US granted refugee status to Afrikaners, citing racial discrimination. South African President Ramaphosa refuted these claims, calling those who left "cowards." The US decision risks exacerbating racial tensions and complicating relations with South Africa.
#
# [India-Pakistan Ceasefire: Fragile Truce]
# A US-brokered ceasefire halted intense India-Pakistan cross-border clashes triggered by a militant attack in Kashmir. Both sides accuse each other of violations, highlighting persistent distrust. The US and international actors played a crucial role in de-escalation, but underlying issues remain unresolved.
#
# [AI Training: Leaner and Decentralized Models]
# AI development focuses on efficiency and accessibility, with Google's Chrome incorporating smaller models and Apple's FastVLM speeding up vision encoding. Prime Intellect's INTELLECT-2 showcases decentralized training, and the Absolute Zero Reasoner (AZR) demonstrates self-evolving reasoning.
#
# [Cybersecurity: EU Database and App Leaks]
# The EU launched its European Vulnerability Database (EUVD). A macOS vulnerability allowed attackers to bypass security prompts. Security researcher Alex Schapiro exposed flaws in the dating app Cerca, leaving user data exposed due to broken security measures.
#
# [Zelensky-Putin: Istanbul Talks Preconditions]
# Zelensky and Putin indicated willingness to talk in Istanbul, but preconditions remain a chasm. Zelensky demands a 30-day ceasefire before negotiations, while Putin wants to address the "root causes" first. International players are involved, but a breakthrough seems unlikely.
#
# [AI Copyright: US and UK Pressure]
# The US Copyright Office head was fired after raising concerns about AI companies using copyrighted material for training. UK artists, including Elton John and Dua Lipa, are urging stronger copyright laws against AI infringement. The debate centers on fair use versus licensing.
#
# [Android Desktop Mode: Google vs Samsung]
# Google is developing a native desktop mode for Android, dubbed "Desktop View," to rival Samsung's DeX. The feature includes a taskbar, resizable windows, and drag-and-drop functionality. This suggests a desire to unify desktop operating system efforts around Android.
#
# [Rust and Zig: Ecosystem Scrutiny]
# Rust's documentation quality varies, impacting the learning curve. Zig faces criticism regarding design choices and performance claims, with some questioning its verbosity and real-world performance compared to C. The focus is on improving developer experience and validating core claims.
#
# [US-China Tariffs: Temporary Truce]
# The US and China agreed to a temporary 90-day reduction in import tariffs. The US will drop tariffs on Chinese goods to 30%, and China will drop tariffs on some US imports to 10%. The agreement offers a temporary reprieve but doesn't resolve fundamental trade imbalances.

# %% [markdown]
# # Publish

# %%
print("========== STATS ==========")
print(f"Total articles: {len(events)}")
print(f"Total sources: {len(sources)}")
print(f"Total used articles: {len(used_events)}")
print(f"Total used sources: {len(used_sources)}")
print(f"Model used: {brief_model}")
print("========== STATS ==========")
# Out:
# ========== STATS ==========
# Total articles: 276
# Total sources: 2
# Total used articles: 49
# Total used sources: 16
# Model used: gemini-2.5-flash-preview-04-17
# ========== STATS ==========

# %%
print(f"# {brief_title}\n")
print(final_brief_text)
# Out:
# # Gaza, Habeas Corpus, Afrikaners, India-Pakistan, AI, Cybersecurity, Zelensky-Putin, Copyright, Android, Rust-Zig, US-China Tariffs
#
# ## What matters now
#
# <u>**Gaza: The Grinding Conflict Deepens Amidst Famine Warnings and West Bank Flare-Ups**</u>
#
# The situation in **Gaza** continues its grim trajectory, marked by intensified **Israeli** military operations leading to significant civilian casualties. The humanitarian crisis is now reaching critical levels, with the **UN** issuing stark warnings of imminent famine. This isn't just a consequence of the fighting; the ongoing **Israeli** blockade of aid is explicitly cited as a primary cause by the **UNRWA** chief, who has accused **Israel** of using food as a weapon.
#
# Ceasefire negotiations remain stalled, a predictable outcome given the fundamental disconnect between the parties. Meanwhile, tensions are boiling over in the **West Bank**, with reports detailing increased settler violence and the displacement of **Palestinians**. Figures like settler **Moshe Sharvit** openly articulate a worldview that dismisses Palestinian claims and justifies settlement expansion, highlighting the ideological underpinnings of this violence.
#
# The information landscape remains heavily contested. While the fact of strikes and casualties is undisputed, narratives diverge sharply. **Israel** maintains its actions are self-defense against **Hamas**, which it claims uses civilian infrastructure. **Hamas** denies this. On the humanitarian front, **Israel** disputes the severity of the hunger crisis, claiming sufficient aid is entering, a direct contradiction to **UNRWA** and IPC reports. The reliability of casualty figures, largely sourced from the **Hamas**-run health ministry, also remains a persistent challenge for independent verification. This isn't just a military conflict; it's a full-blown information war, making it difficult to discern the unvarnished truth on the ground.
#
# <u>**Trump Administration Floats Suspending Habeas Corpus, Raising Constitutional Alarms**</u>
#
# In a move that has sent ripples through legal and political circles, **White House Deputy Chief of Staff Stephen Miller** has publicly stated the **Trump administration** is actively considering suspending **habeas corpus**. Miller's argument hinges on the constitutional provision allowing suspension during rebellion or invasion, a justification he appears to link to recent court challenges against immigration detentions.
#
# This isn't a minor policy tweak; it's a direct challenge to a fundamental legal principle allowing individuals to contest their detention in court. The historical context is limited – suspensions have occurred during the Civil War and in specific wartime scenarios like post-Pearl Harbor Hawaii. Legal experts, like attorney **Marc Elias**, are quick to point out that the authority to suspend **habeas corpus** traditionally rests with Congress, not the executive branch.
#
# The timing is notable, coming amidst judicial pushback against the administration's detention practices, including cases involving immigrants and students detained during protests. The administration's willingness to explore such a drastic measure underscores its frustration with judicial checks on its authority and signals a potential showdown between the executive and the courts. The implications for civil liberties, particularly for non-citizens and those challenging government actions, are significant and potentially far-reaching.
#
# <u>**US-South Africa Relations Sour Over Afrikaner Refugee Status**</u>
#
# Diplomatic friction between the **US** and **South Africa** has intensified following the arrival of a group of white **Afrikaners** granted refugee status in the United States. The move, championed by the **Trump administration** which claims **Afrikaners** face racial discrimination and land seizures, has been met with sharp condemnation from **Pretoria**.
#
# **South African President Cyril Ramaphosa** didn't mince words, calling those who left "cowards" and directly refuting the US assessment of the situation as "not true." His government denies any persecution of white **Afrikaners**. This public spat highlights not only differing views on South Africa's complex domestic issues but also broader disagreements between the two nations, including South Africa's stance on the **Gaza** conflict.
#
# The US decision to grant refugee status, particularly under an administration that has often sought to restrict immigration, appears politically charged. While claims of discrimination and farm attacks in South Africa are real concerns for some, the narrative of widespread persecution or "genocide" (as previously claimed by figures like **Elon Musk**) has been widely discredited. The US move risks exacerbating racial tensions within South Africa and complicates its relationship with a key African partner, all while potentially playing to a specific political base in the US.
#
# <u>**India-Pakistan Ceasefire Holds Precariously After US Mediation**</u>
#
# Days of intense cross-border clashes between **India** and **Pakistan**, triggered by a militant attack in Indian-administered **Kashmir**, were halted by a US-brokered ceasefire. The de-escalation, announced by **President Trump**, came after a dangerous exchange of fire, including Indian strikes inside Pakistan.
#
# While the ceasefire initially took hold, its fragility was immediately apparent, with both sides quickly accusing the other of violations. This highlights the persistent lack of trust and the deep-seated nature of the **Kashmir** dispute. The US, along with other international actors, played a crucial role in pulling the two nuclear-armed neighbors back from the brink, underscoring the global stakes involved in any escalation in the region.
#
# Despite the temporary calm, the underlying issues remain unresolved. **India** maintains its firm stance against cross-border terrorism, which it attributes to **Pakistan**, while **Pakistan** denies involvement in attacks and seeks third-party mediation on **Kashmir**. The conflicting claims regarding ceasefire violations and even the extent of US mediation versus bilateral military talks underscore the difficulty in achieving a lasting peace. This ceasefire is less a solution and more a pause, bought by external pressure, in a conflict perpetually on the edge.
#
# <u>**AI Training Gets Leaner and More Decentralized**</u>
#
# Recent developments in the AI space point towards a focus on efficiency and accessibility. **Google's Chrome** is incorporating a significantly smaller text embedding model through quantization, promising faster updates and better performance on devices. Similarly, **Apple's FastVLM** aims to speed up vision encoding for models that process both images and text, crucial for handling high-resolution visual data more efficiently.
#
# Beyond optimization, there's movement towards decentralized training. **Prime Intellect's INTELLECT-2** showcases a large model trained via globally distributed reinforcement learning, suggesting paths away from massive, centralized compute clusters. Adding another layer, the **Absolute Zero Reasoner (AZR)** demonstrates self-evolving reasoning capabilities without relying on external, human-curated data, hinting at more autonomous AI development.
#
# Collectively, these advancements signal a push to make powerful AI models more practical for wider deployment, including on edge devices, and potentially democratize their development. While the claims from some of these projects (like Prime Intellect) still require independent verification, the trend towards more efficient architectures and decentralized training methods is clear and could reshape the AI landscape, reducing the dominance of a few large players.
#
# <u>**Digital Defenses Under Scrutiny: EU Database, macOS Bypass, and Dating App Leaks**</u>
#
# A flurry of security news underscores the constant battle against digital vulnerabilities across different fronts. The **EU** has officially launched its **European Vulnerability Database (EUVD)**, a move seen by some as a response to concerns about the reliability and funding of US vulnerability tracking efforts managed by **CISA** and **MITRE**. This signals a potential shift towards greater European autonomy in cybersecurity information sharing.
#
# Meanwhile, a now-patched vulnerability in **macOS (CVE-2025-31250)** allowed attackers to spoof permission prompts, potentially bypassing Apple's **TCC** (Transparency, Consent, and Control) system and gaining unauthorized access to sensitive data. This highlights the persistent challenge of securing even sophisticated operating systems against clever social engineering tactics enabled by technical flaws.
#
# Adding to the concerns, security researcher **Alex Schapiro** exposed significant flaws in the dating app **Cerca**, including broken one-time passwords and open data endpoints, which left user data, including phone numbers and potentially passport information, exposed. This serves as a stark reminder that even apps handling highly sensitive personal information can have fundamental security failures, often due to rushed development or a lack of security expertise, contradicting privacy policy claims of "industry-standard measures."
#
# <u>**Zelensky and Putin Eye Istanbul Talks, But Conditions Remain a Chasm**</u>
#
# A potential path to de-escalation has emerged with both **Ukrainian President Zelensky** and **Russian President Putin** indicating willingness to hold direct talks in Istanbul, Turkey. This follows a push from European leaders, including the UK, France, Germany, and Poland, who recently visited Kyiv and called for a ceasefire.
#
# However, the devil, as always, is in the details – specifically, the preconditions. **Zelensky** insists on a 30-day ceasefire *before* any negotiations begin, viewing Putin's offer with suspicion, potentially as a trap. **Putin**, conversely, wants to address the "root causes" of the conflict *first*, before agreeing to a truce. This fundamental disagreement on sequencing creates a significant hurdle, suggesting that while both sides might be willing to talk, they remain far apart on the terms.
#
# The involvement of international players, including the US (with **Donald Trump** urging Ukraine to accept talks) and European nations considering further sanctions, adds layers of complexity. While Turkey's offer to host is a positive sign for facilitating dialogue, the gap between Kyiv's demand for a ceasefire and Moscow's insistence on discussing underlying issues first makes a breakthrough appear unlikely in the immediate term. The offer is on the table, but the path to actually sitting down remains obstructed by incompatible demands.
#
# <u>**AI Copyright Clash Intensifies as US Copyright Head Fired Amidst UK Pressure**</u>
#
# The simmering conflict between AI development and copyright protection has flared up significantly. The head of the **US Copyright Office, Shira Perlmutter**, was reportedly fired shortly after her office released a report raising concerns about AI companies' use of copyrighted material for training. This move, particularly under the **Trump administration** which also fired the Librarian of Congress, has been criticized by figures like **Rep. Joe Morelle** as a "power grab" potentially linked to pressure from AI industry figures like **Elon Musk**.
#
# This development in the US coincides with growing pressure in the **UK**, where prominent artists, including **Elton John** and **Dua Lipa**, have signed a letter urging the government to strengthen copyright laws against AI infringement. They argue that without updated protections, their work is being effectively given away to tech firms, threatening the UK's creative sector.
#
# The debate is now squarely focused on whether using copyrighted material for AI training constitutes fair use or requires licensing and compensation. The firing of a key US official responsible for copyright policy, immediately after her office highlighted concerns, sends a chilling signal about potential political interference in this crucial debate. Coupled with legislative pushes in the UK, the stage is set for a significant international battle over the future of intellectual property in the age of generative AI.
#
# <u>**Google Quietly Building Android Desktop Mode to Rival Samsung DeX**</u>
#
# It appears **Google** is finally getting serious about turning Android phones into pocket PCs. Reports indicate the company is developing a native desktop mode for Android, currently dubbed "Desktop View," designed to provide a PC-like multitasking experience when connected to an external display.
#
# The feature, still in early development and hidden within Android beta code, includes familiar elements like a taskbar, resizable windows, and drag-and-drop functionality. This effort is clearly aimed at competing with **Samsung's** well-established **DeX** platform, which has offered a similar capability for years.
#
# Google's move suggests a desire to unify its desktop operating system efforts, potentially consolidating around Android's growing capabilities. While it's unlikely to replace traditional desktops anytime soon, a robust native desktop mode could significantly enhance Android's utility for productivity and potentially make it a more compelling platform for users seeking a single device for both mobile and desktop tasks. The timeline for release remains uncertain, likely tied to future Android versions.
#
# <u>**Rust and Zig Ecosystems Under the Microscope: Docs, Learning, and Claims**</u>
#
# Analysis within the developer community continues to scrutinize the ecosystems of newer systems programming languages like **Rust** and **Zig**. A review of **Rust** crates highlights the variable quality of documentation – some offer excellent tutorials and explanations, while others lean heavily on basic API references, impacting the learning curve for newcomers. Efforts by consultancies like **Corrode Rust Consulting** aim to flatten this curve with practical advice, emphasizing the unique mental model required by Rust's borrow checker.
#
# Meanwhile, **Zig** is facing critical assessment regarding its design choices and performance claims. While its cross-compilation tooling is widely praised and adopted, some critics question the language's verbosity and whether its performance truly surpasses C in practice, pointing to potentially flawed benchmarks. The debate also touches on **Zig's** approach to undefined behavior and safety in production environments.
#
# These discussions reflect the ongoing evaluation of these languages as potential alternatives to C/C++. For **Rust**, the focus is on improving developer experience through better documentation and learning resources. For **Zig**, the challenge is validating its core claims and addressing concerns about its design trade-offs as it seeks broader adoption beyond its successful tooling niche.
#
# <u>**US and China Announce Temporary Tariff Truce**</u>
#
# In a notable de-escalation of the trade war, the **US** and **China** have agreed to a temporary 90-day reduction in import tariffs. The deal, reached after talks in Switzerland, will see US tariffs on Chinese goods drop to 30% and Chinese tariffs on some US imports fall to 10%.
#
# Both sides are framing the agreement positively, with **President Trump** calling it a "total reset" and China's Commerce Ministry seeing it as a step to "resolve differences." However, the 90-day duration underscores the provisional nature of the truce. The US measures still include a significant component specifically targeting fentanyl trade, indicating that not all points of friction are purely economic.
#
# While the agreement offers a temporary reprieve for businesses and consumers impacted by the tariffs, it doesn't resolve the fundamental trade imbalances or address deeper structural issues. The conflicting accounts of who initiated the talks and differing interpretations of the agreement's significance highlight the persistent underlying tensions. This is less a peace treaty and more a timeout, allowing both sides to regroup before potentially resuming hostilities or negotiating a more durable arrangement.

# %%
# # 本地测试发布report
# from datetime import datetime
# import requests

# body = {
#     "title": brief_title,
#     "content": final_brief_text,
#     "totalArticles": len(events),
#     "totalSources": len(sources),
#     "usedArticles": len(used_events),
#     "usedSources": len(used_sources),
#     "tldr": tldr,
#     "model_author": brief_model,
#     "createdAt": datetime.now().isoformat(),
#     "clustering_params": {
#         "umap": {
#             "n_neighbors": 10
#         },
#         "hdbscan": {
#             "epsilon": 0.0,
#             "min_samples": 0,
#             "min_cluster_size": 3
#         }
#     },
# }

# endpoint = "http://localhost:8787/reports/report"  # 修改为本地后端地址

# try:
#     response = requests.post(
#         endpoint,
#         json=body,
#         headers={"Authorization": f"Bearer {os.environ.get('MERIDIAN_SECRET_KEY')}"},
#     )
#     print("发布成功:", response.json())
#     print("现在可以通过浏览器访问: http://localhost:3000/briefs/latest")
# except Exception as e:
#     print(f"发布失败: {e}")
# Out:
# 发布失败: HTTPConnectionPool(host='localhost', port=8787): Max retries exceeded with url: /reports/report (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x3951d1b70>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
from datetime import datetime
import requests
import os

body = {
    "title": brief_title,
    "content": final_brief_text,
    "totalArticles": len(events),
    "totalSources": len(sources),
    "usedArticles": len(used_events),
    "usedSources": len(used_sources),
    "tldr": tldr,
    "model_author": brief_model,
    "createdAt": datetime.now().isoformat(),
    "clustering_params": {
        "umap": {
            "n_neighbors": 10
        },
        "hdbscan": {
            "epsilon": 0.0,
            "min_samples": 0,
            "min_cluster_size": 3
        }
    },
}

# 修改为您的Cloudflare Workers域名
endpoint = "https://meridian-backend.swj299792458.workers.dev/reports/report"

try:
    response = requests.post(
        endpoint,
        json=body,
        headers={"Authorization": f"Bearer {os.environ.get('MERIDIAN_SECRET_KEY')}"},
        timeout=30  # 增加超时时间，远程调用可能需要更长时间
    )
    
    # 检查响应状态码
    if response.status_code == 200:
        print(f"发布成功: {response.json()}")
        print(f"可以通过以下链接访问: https://meridian.your-frontend-domain.com/briefs/latest")
    else:
        print(f"发布失败: 状态码 {response.status_code}")
        print(f"错误信息: {response.text}")
        
except Exception as e:
    print(f"发布过程中出现异常: {e}")
# Out:
# 发布成功: {'success': True}
# 可以通过以下链接访问: https://meridian.your-frontend-domain.com/briefs/latest

# %%
# from datetime import datetime
# import requests

# body = {
#     "title": brief_title,
#     "content": final_brief_text,
#     "totalArticles": len(events),
#     "totalSources": len(sources),
#     "usedArticles": len(used_events),
#     "usedSources": len(used_sources),
#     "tldr": tldr,
#     "model_author": brief_model,
#     "createdAt": datetime.now().isoformat(),
#     "clustering_params": {
#   "umap": {
#     "n_neighbors": 10
#   },
#   "hdbscan": {
#     "epsilon": 0.0,
#     "min_samples": 0,
#     "min_cluster_size": 3
#   }
# },
# }

# endpoint = "https://meridian-production.alceos.workers.dev/reports/report"

# response = requests.post(
#     endpoint,
#     json=body,
#     headers={"Authorization": f"Bearer {os.environ.get('MERIDIAN_SECRET_KEY')}"},
# )
# print(response.json())

# %% [markdown]
# ### Meridian 项目简历描述
#
# #### Meridian: 个人智能情报系统
#
# 开发了一个端到端的个人智能情报系统，自动收集、分析全球新闻并生成每日深度简报。该系统结合了先进的机器学习和大型语言模型技术，实现了从数据采集到内容生成的完整流程：
#
# - **数据获取与处理**：设计和实现了基于Cloudflare Workers的分布式爬虫系统，自动从多个来源抓取和处理新闻文章
# - **智能聚类与分析**：利用UMAP和HDBSCAN算法进行文章聚类，结合Gemini 2.5/2.0模型对新闻集群进行深度分析和内容提取
# - **高质量内容生成**：开发了多阶段提示工程系统，利用LLM生成结构化、分析性强的每日简报
# - **云原生架构**：采用Cloudflare Workers、Durable Objects和队列系统构建可扩展的无服务器架构
#
# **技术栈**：Python、TypeScript、Cloudflare Workers、LLMs (Gemini)、UMAP/HDBSCAN、pandas、自然语言处理
#
# **成果**：实现了媲美专业情报机构的个人化新闻分析系统，将数小时的阅读和分析压缩为20-30分钟的精华简报，每日自动处理超过数千篇文章并识别百余个关键事件集群。
